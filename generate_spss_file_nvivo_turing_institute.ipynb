# %% [markdown]
# # Generate SPSS files, for 'normal' (IR) NVivo files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import re
from string import printable
import ftfy
from scipy.stats import chi2_contingency

# %%
# widen display to allow long text strings to be more visible on screen
pd.set_option('display.max_colwidth',2000)

# %%
# %pwd
# Out:
# '\\\\ads\\filestore\\Deaf_Studies\\Deaf\\nfrc\\LeDeR confidential\\Data Entry\\Avon\\reviews_leder_revised_codes\\python_notebooks'

# %% [markdown]
# # read in master nvivo_df

# %%
master_nvivo_df = pd.read_pickle('master_nvivo_df.pickle')

# %% [markdown]
# # Create sub-sample
# based on document type

# %%
normal_df = master_nvivo_df[master_nvivo_df.case_file_type_atext=='Normal']

# %% [raw]
# normal_df.head(2)

# %%
list(normal_df.columns)
# Out:
# ['AAA_screening',
#  'AAA_screening_atext',
#  'AAA_screening_no',
#  'AAA_screening_no_atext',
#  'AAA_screening_yes',
#  'AAA_screening_yes_atext',
#  'AP_agencies',
#  'AP_agencies_atext',
#  'AP_completed_DNACPR',
#  'AP_completed_DNACPR_atext',
#  'AP_completed_EOL_care',
#  'AP_completed_EOL_care_atext',
#  'AP_completed_LD_awareness',
#  'AP_completed_LD_awareness_atext',
#  'AP_completed_MCA',
#  'AP_completed_MCA_atext',
#  'AP_completed_agencies',
#  'AP_completed_agencies_atext',
#  'AP_completed_care_coordination',
#  'AP_completed_care_coordination_atext',
#  'AP_completed_documentation',
#  'AP_completed_documentation_atext',
#  'AP_completed_family',
#  'AP_completed_family_atext',
#  'AP_completed_other',
#  'AP_completed_other_atext',
#  'AP_completed_reasonable_adjustments',
#  'AP_completed_reasonable_adjustments_atext',
#  'AP_completed_role_paid_carers',
#  'AP_completed_role_paid_carers_atext',
#  'AP_person',
#  'AP_person_atext',
#  'AP_raised_DNACPR',
#  'AP_raised_DNACPR_atext',
#  'AP_raised_EOL_care',
#  'AP_raised_EOL_care_atext',
#  'AP_raised_LD_awareness',
#  'AP_raised_LD_awareness_atext',
#  'AP_raised_MCA',
#  'AP_raised_MCA_atext',
#  'AP_raised_agencies',
#  'AP_raised_agencies_atext',
#  'AP_raised_care_coordination',
#  'AP_raised_care_coordination_atext',
#  'AP_raised_documentation',
#  'AP_raised_documentation_atext',
#  'AP_raised_family',
#  'AP_raised_family_atext',
#  'AP_raised_other',
#  'AP_raised_other_atext',
#  'AP_raised_reasonable_adjustments',
#  'AP_raised_reasonable_adjustments_atext',
#  'AP_raised_role_paid_carers',
#  'AP_raised_role_paid_carers_atext',
#  'Absences_1_to_4_per_month',
#  'Absences_1_to_4_per_month_atext',
#  'Absences_frequency',
#  'Absences_frequency_atext',
#  'Accident_incident',
#  'Accident_incident_atext',
#  'Accommodation',
#  'Accommodation_atext',
#  'Accommodation_type',
#  'Accommodation_type_atext',
#  'Acm_Change_1Yr_Num',
#  'Acm_Change_1Yr_Num_atext',
#  'Acm_Change_1Yr_one',
#  'Acm_Change_1Yr_one_atext',
#  'Acm_Change_1Yr_over_three',
#  'Acm_Change_1Yr_over_three_atext',
#  'Acm_Change_1Yr_three',
#  'Acm_Change_1Yr_three_atext',
#  'Acm_Change_1Yr_two',
#  'Acm_Change_1Yr_two_atext',
#  'Acm_Iss_1Yr',
#  'Acm_Iss_1Yr_atext',
#  'Acm_Iss_Evr',
#  'Acm_Iss_Evr_atext',
#  'Acm_Multi_Changes',
#  'Acm_Multi_Changes_atext',
#  'Acm_TOD_5years_and_more',
#  'Acm_TOD_5years_and_more_atext',
#  'Acm_TOD_dur_LT_10years',
#  'Acm_TOD_dur_LT_10years_atext',
#  'Acm_TOD_dur_LT_1month',
#  'Acm_TOD_dur_LT_1month_atext',
#  'Acm_TOD_dur_LT_1year',
#  'Acm_TOD_dur_LT_1year_atext',
#  'Acm_TOD_dur_LT_5years',
#  'Acm_TOD_dur_LT_5years_atext',
#  'Acm_TOD_dur_cat',
#  'Acm_TOD_dur_cat_atext',
#  'Acm_change_reas_acm',
#  'Acm_change_reas_acm_atext',
#  'Acm_change_reas_better_accom',
#  'Acm_change_reas_better_accom_atext',
#  'Acm_change_reas_closure',
#  'Acm_change_reas_closure_atext',
#  'Acm_change_reas_pers_condition',
#  'Acm_change_reas_pers_condition_atext',
#  'Acm_change_reas_unknown',
#  'Acm_change_reas_unknown_atext',
#  'Acm_change_reason_cat',
#  'Acm_change_reason_cat_atext',
#  'Acm_hist_institution',
#  'Acm_hist_institution_atext',
#  'Acm_number_occupants',
#  'Acm_number_occupants_atext',
#  'Action_points_raised',
#  'Action_points_raised_atext',
#  'Activities',
#  'Activities_atext',
#  'Adopted',
#  'Adopted_atext',
#  'Advocate',
#  'Advocate_atext',
#  'Advocate_no',
#  'Advocate_no_atext',
#  'Advocate_yes',
#  'Advocate_yes_atext',
#  'Agency_safeguarding_referral',
#  'Agency_safeguarding_referral_atext',
#  'Alcohol_misuse',
#  'Alcohol_misuse_atext',
#  'Alcohol_misuse_in_past',
#  'Alcohol_misuse_in_past_atext',
#  'Alcohol_misuse_yes',
#  'Alcohol_misuse_yes_atext',
#  'Allergies',
#  'Allergies_atext',
#  'Anxiety',
#  'Anxiety_atext',
#  'Any_aids_employed',
#  'Any_aids_employed_atext',
#  'Appointment_cancelled',
#  'Appointment_cancelled_atext',
#  'Aspiration_before_last_year',
#  'Aspiration_before_last_year_atext',
#  'Aspiration_never',
#  'Aspiration_never_atext',
#  'Aspiration_unknown',
#  'Aspiration_unknown_atext',
#  'Aspiration_within_last_year',
#  'Aspiration_within_last_year_atext',
#  'Austism_no',
#  'Austism_no_atext',
#  'Autism_adult_diagnosis',
#  'Autism_adult_diagnosis_atext',
#  'Autism_childhood_diagnosis',
#  'Autism_childhood_diagnosis_atext',
#  'BMI',
#  'BMI_atext',
#  'Behaviour_problems',
#  'Behaviour_problems_atext',
#  'Best_practice',
#  'Best_practice_atext',
#  'Bipolar',
#  'Bipolar_atext',
#  'Blood_pressure_high',
#  'Blood_pressure_high_atext',
#  'Blood_pressure_low',
#  'Blood_pressure_low_atext',
#  'Bowel_cancer_screening',
#  'Bowel_cancer_screening_atext',
#  'Bowel_cancer_screening_no',
#  'Bowel_cancer_screening_no_atext',
#  'Bowel_cancer_screening_yes',
#  'Bowel_cancer_screening_yes_atext',
#  'Breast_cancer_screening',
#  'Breast_cancer_screening_atext',
#  'Breast_cancer_screening_no',
#  'Breast_cancer_screening_no_atext',
#  'Breast_cancer_screening_yes',
#  'Breast_cancer_screening_yes_atext',
#  'CF_care_coordination',
#  'CF_care_coordination_atext',
#  'CF_care_provision',
#  'CF_care_provision_atext',
#  'CF_care_training_need',
#  'CF_care_training_need_atext',
#  'CF_family_or_environment',
#  'CF_family_or_environment_atext',
#  'CF_healthcare_delay_diagnosis',
#  'CF_healthcare_delay_diagnosis_atext',
#  'CF_healthcare_delay_primary',
#  'CF_healthcare_delay_primary_atext',
#  'CF_healthcare_delay_treatment',
#  'CF_healthcare_delay_treatment_atext',
#  'CF_pers_mental_health',
#  'CF_pers_mental_health_atext',
#  'CF_pers_self_harm',
#  'CF_pers_self_harm_atext',
#  'CF_person',
#  'CF_person_atext',
#  'CF_service_provision',
#  'CF_service_provision_atext',
#  'Cancer',
#  'Cancer_atext',
#  'Cancer_date_referral',
#  'Cancer_date_referral_atext',
#  'Cancer_date_symptoms_noticed',
#  'Cancer_date_symptoms_noticed_atext',
#  'Cancer_date_symptoms_reported',
#  'Cancer_date_symptoms_reported_atext',
#  'Cancer_investigations',
#  'Cancer_investigations_atext',
#  'Cancer_investigations_before_referral',
#  'Cancer_investigations_before_referral_atext',
#  'Cancer_investigations_ordered',
#  'Cancer_investigations_ordered_atext',
#  'Cancer_main_symptom',
#  'Cancer_main_symptom_atext',
#  'Cancer_spread_metastasis',
#  'Cancer_spread_metastasis_atext',
#  'Cancer_stage',
#  'Cancer_stage_2',
#  'Cancer_stage_2_atext',
#  'Cancer_stage_3',
#  'Cancer_stage_3_atext',
#  'Cancer_stage_4',
#  'Cancer_stage_4_atext',
#  'Cancer_stage_atext',
#  'Cancer_symptoms_reported_to',
#  'Cancer_symptoms_reported_to_atext',
#  'Care_plan_EOL',
#  'Care_plan_EOL_atext',
#  'Care_plan_dementia',
#  'Care_plan_dementia_atext',
#  'Care_plan_diabetes',
#  'Care_plan_diabetes_atext',
#  'Care_plan_epilepsy',
#  'Care_plan_epilepsy_atext',
#  'Care_plan_other',
#  'Care_plan_other_atext',
#  'Care_plans',
#  'Care_plans_atext',
#  'Cervical_cancer_screening',
#  'Cervical_cancer_screening_atext',
#  'Cervical_cancer_screening_no',
#  'Cervical_cancer_screening_no_atext',
#  'Cervical_cancer_screening_yes',
#  'Cervical_cancer_screening_yes_atext',
#  'Child_in_need',
#  'Child_in_need_atext',
#  'Choking_before_last_year',
#  'Choking_before_last_year_atext',
#  'Choking_never',
#  'Choking_never_atext',
#  'Choking_unknown',
#  'Choking_unknown_atext',
#  'Choking_within_last_year',
#  'Choking_within_last_year_atext',
#  'Circumstances_of_death',
#  'Circumstances_of_death_atext',
#  'Clinical_COPD',
#  'Clinical_COPD_atext',
#  'Clinical_DVT',
#  'Clinical_DVT_atext',
#  'Clinical_UTI',
#  'Clinical_UTI_atext',
#  'Clinical_asthma',
#  'Clinical_asthma_atext',
#  'Clinical_autism',
#  'Clinical_autism_atext',
#  'Clinical_blood_pressure',
#  'Clinical_blood_pressure_atext',
#  'Clinical_cardiovascular_problem',
#  'Clinical_cardiovascular_problem_atext',
#  'Clinical_cerebral_palsy',
#  'Clinical_cerebral_palsy_atext',
#  'Clinical_condition',
#  'Clinical_condition_atext',
#  'Clinical_continence',
#  'Clinical_continence_atext',
#  'Clinical_degenerative_condition',
#  'Clinical_degenerative_condition_atext',
#  'Clinical_dementia',
#  'Clinical_dementia_atext',
#  'Clinical_diabetes',
#  'Clinical_diabetes_atext',
#  'Clinical_double_incontinence',
#  'Clinical_double_incontinence_atext',
#  'Clinical_downs',
#  'Clinical_downs_atext',
#  'Clinical_feacal_incontinence',
#  'Clinical_feacal_incontinence_atext',
#  'Clinical_genetic_condition',
#  'Clinical_genetic_condition_atext',
#  'Clinical_high_cholesterol',
#  'Clinical_high_cholesterol_atext',
#  'Clinical_history_chest_infections',
#  'Clinical_history_chest_infections_atext',
#  'Clinical_history_falls',
#  'Clinical_history_falls_atext',
#  'Clinical_kidney_problems',
#  'Clinical_kidney_problems_atext',
#  'Clinical_osteoporisis',
#  'Clinical_osteoporisis_atext',
#  'Clinical_pneumonia_aspiration',
#  'Clinical_pneumonia_aspiration_atext',
#  'Clinical_pneumonia_infectious',
#  'Clinical_pneumonia_infectious_atext',
#  'Clinical_prostate_problems',
#  'Clinical_prostate_problems_atext',
#  'Clinical_sepsis',
#  'Clinical_sepsis_atext',
#  'Clinical_urinary_incontinent',
#  'Clinical_urinary_incontinent_atext',
#  'Communication_abilities',
#  'Communication_abilities_atext',
#  'Constipation',
#  'Constipation_atext',
#  'Continence_aids',
#  'Continence_aids_atext',
#  'Contraception',
#  'Contraception_atext',
#  'Contributory_factor_COD',
#  'Contributory_factor_COD_atext',
#  'DNACPR',
#  'DNACPR_atext',
#  'DNACPR_comments',
#  'DNACPR_comments_atext',
#  'Daytime_activities',
#  'Daytime_activities_atext',
#  'Daytime_independent_activities',
#  'Daytime_independent_activities_atext',
#  'Death_from_fall',
#  'Death_from_fall_atext',
#  'Death_from_other_accidents',
#  'Death_from_other_accidents_atext',
#  'Death_from_road_accident',
#  'Death_from_road_accident_atext',
#  'Death_from_suicide',
#  'Death_from_suicide_atext',
#  'Dental_issues',
#  'Dental_issues_atext',
#  'Dental_last_check',
#  'Dental_last_check_atext',
#  'Dental_last_check_date',
#  'Dental_last_check_date_atext',
#  'Dental_regular_care',
#  'Dental_regular_care_atext',
#  'Depression',
#  'Depression_atext',
#  'Diabetes_type_1',
#  'Diabetes_type_1_atext',
#  'Diabetes_type_2',
#  'Diabetes_type_2_atext',
#  'Diabetes_type_unspecified',
#  'Diabetes_type_unspecified_atext',
#  'Difficulties_services_with_carer',
#  'Difficulties_services_with_carer_atext',
#  'Domestic_violence_household',
#  'Domestic_violence_household_atext',
#  'Drug_misuse',
#  'Drug_misuse_atext',
#  'Drug_misuse_in_past',
#  'Drug_misuse_in_past_atext',
#  'Drug_misuse_yes',
#  'Drug_misuse_yes_atext',
#  'Eating_disorder',
#  'Eating_disorder_atext',
#  'Employment',
#  'Employment_at_TOD',
#  'Employment_at_TOD_atext',
#  'Employment_atext',
#  'Employment_ever_no',
#  'Employment_ever_no_atext',
#  'Employment_ever_yes',
#  'Employment_ever_yes_atext',
#  'Employment_paid_ever',
#  'Employment_paid_ever_atext',
#  'Epi_care_plan',
#  'Epi_care_plan_atext',
#  'Epi_frequecy_duration',
#  'Epi_frequecy_duration_atext',
#  'Epi_manage_descr',
#  'Epi_manage_descr_atext',
#  'Epilepsy',
#  'Epilepsy_atext',
#  'Event_of_death_issues',
#  'Event_of_death_issues_atext',
#  'Fam_carers_supported',
#  'Fam_carers_supported_atext',
#  'Fam_carers_supported_no',
#  'Fam_carers_supported_no_atext',
#  'Fam_carers_supported_yes',
#  'Fam_carers_supported_yes_atext',
#  'Fam_contact_child',
#  'Fam_contact_child_atext',
#  'Fam_contact_dail1y',
#  'Fam_contact_dail1y_atext',
#  'Fam_contact_few_times_yearly',
#  'Fam_contact_few_times_yearly_atext',
#  'Fam_contact_frequently',
#  'Fam_contact_frequently_atext',
#  'Fam_contact_infrequently',
#  'Fam_contact_infrequently_atext',
#  'Fam_contact_less_than_yearly',
#  'Fam_contact_less_than_yearly_atext',
#  'Fam_contact_monthly',
#  'Fam_contact_monthly_atext',
#  'Fam_contact_never',
#  'Fam_contact_never_atext',
#  'Fam_contact_other',
#  'Fam_contact_other_atext',
#  'Fam_contact_parent',
#  'Fam_contact_parent_atext',
#  'Fam_contact_sibling',
#  'Fam_contact_sibling_atext',
#  'Fam_contact_unspecified',
#  'Fam_contact_unspecified_atext',
#  'Fam_contact_weekly',
#  'Fam_contact_weekly_atext',
#  'Fam_listened_to_no',
#  'Fam_listened_to_no_atext',
#  'Fam_listened_to_yes',
#  'Fam_listened_to_yes_atext',
#  'Fam_rel_concerns',
#  'Fam_rel_concerns_atext',
#  'Fam_rel_poor',
#  'Fam_rel_poor_atext',
#  'Fam_rel_seemed_good',
#  'Fam_rel_seemed_good_atext',
#  'Fam_rel_unknown',
#  'Fam_rel_unknown_atext',
#  'Families_listened_to',
#  'Families_listened_to_atext',
#  'Family_carers',
#  'Family_carers_atext',
#  'Family_carers_no',
#  'Family_carers_no_atext',
#  'Family_carers_views_of_death',
#  'Family_carers_views_of_death_atext',
#  'Family_carers_yes',
#  'Family_carers_yes_atext',
#  'Family_concerns_about_death',
#  'Family_concerns_about_death_atext',
#  'Family_contact_regularity',
#  'Family_contact_regularity_atext',
#  'Family_contacts_members',
#  'Family_contacts_members_atext',
#  'Family_relationships',
#  'Family_relationships_atext',
#  'Family_relative_deceased',
#  'Family_relative_deceased_atext',
#  'Family_safeguarding_referral',
#  'Family_safeguarding_referral_atext',
#  'Fear_of_doctor_or_treatment',
#  'Fear_of_doctor_or_treatment_atext',
#  'Fear_of_doctor_sensitization',
#  'Fear_of_doctor_sensitization_atext',
#  'Fiinancial_abuse',
#  'Fiinancial_abuse_atext',
#  'Financial_abuse',
#  'Financial_abuse_atext',
#  'Financial_circumstances',
#  'Financial_circumstances_atext',
#  'Good_practice',
#  'Good_practice_EOL',
#  'Good_practice_EOL_atext',
#  'Good_practice_MCA',
#  'Good_practice_MCA_atext',
#  'Good_practice_atext',
#  'Good_practice_care_coordination',
#  'Good_practice_care_coordination_atext',
#  'Good_practice_care_provider',
#  'Good_practice_care_provider_atext',
#  'Good_practice_primary',
#  'Good_practice_primary_atext',
#  'Good_practice_review',
#  'Good_practice_review_atext',
#  'Good_practice_secondary',
#  'Good_practice_secondary_atext',
#  'Good_practice_transition',
#  'Good_practice_transition_atext',
#  'Good_verbal_communication',
#  'Good_verbal_communication_atext',
#  'Health',
#  'Health_action_plan',
#  'Health_action_plan_atext',
#  'Health_action_plan_no',
#  'Health_action_plan_no_atext',
#  'Health_action_plan_yes',
#  'Health_action_plan_yes_atext',
#  'Health_atext',
#  'Health_checks',
#  'Health_checks_annual_LD',
#  'Health_checks_annual_LD_atext',
#  'Health_checks_anual_LD',
#  'Health_checks_anual_LD_atext',
#  'Health_checks_atext',
#  'Healthcare_institutions_processes',
#  'Healthcare_institutions_processes_atext',
#  'Hearing_problems',
#  'Hearing_problems_atext',
#  'Hearing_problems_no',
#  'Hearing_problems_no_atext',
#  'Hearing_problems_yes',
#  'Hearing_problems_yes_atext',
#  'Height',
#  'Height_atext',
#  'Height_weight_BMI',
#  'Height_weight_BMI_atext',
#  'Holidays',
#  'Holidays_atext',
#  'Hospice',
#  'Hospice_atext',
#  'Hospital_communication_document',
#  'Hospital_communication_document_atext',
#  'Hospital_communication_document_no',
#  'Hospital_communication_document_no_atext',
#  'Hospital_communication_document_yes',
#  'Hospital_communication_document_yes_atext',
#  'Housing_provider',
#  'Housing_provider_atext',
#  'Immunised_against_flu',
#  'Immunised_against_flu_atext',
#  'Immunised_against_flu_no',
#  'Immunised_against_flu_no_atext',
#  'Immunised_against_flu_yes',
#  'Immunised_against_flu_yes_atext',
#  'Independently_mobile',
#  'Independently_mobile_atext',
#  'Informal_supp_family_other_house',
#  'Informal_supp_family_other_house_atext',
#  'Informal_supp_friends_other_house',
#  'Informal_supp_friends_other_house_atext',
#  'Informal_supp_friends_same_house',
#  'Informal_supp_friends_same_house_atext',
#  'Informal_support',
#  'Informal_support_atext',
#  'Institution_long_stay_hospital',
#  'Institution_long_stay_hospital_atext',
#  'Interpersonal_relationships',
#  'Interpersonal_relationships_atext',
#  'Issues',
#  'Issues_agencies',
#  'Issues_agencies_atext',
#  'Issues_atext',
#  'Issues_family',
#  'Issues_family_atext',
#  'Issues_person',
#  'Issues_person_atext',
#  'Known_to_police',
#  'Known_to_police_atext',
#  'Known_to_police_in_past',
#  'Known_to_police_in_past_atext',
#  'Known_to_police_yes',
#  'Known_to_police_yes_atext',
#  'LA_childrens_social_services',
#  'LA_childrens_social_services_atext',
#  'LA_education',
#  'LA_education_atext',
#  'LA_support_day_services_LD',
#  'LA_support_day_services_LD_atext',
#  'LA_support_day_services_generic',
#  'LA_support_day_services_generic_atext',
#  'LA_support_respite',
#  'LA_support_respite_atext',
#  'LA_support_social_worker_CLDT',
#  'LA_support_social_worker_CLDT_atext',
#  'LA_support_social_worker_generic',
#  'LA_support_social_worker_generic_atext',
#  'LA_support_worker',
#  'LA_support_worker_atext',
#  'LD_severity',
#  'LD_severity_atext',
#  'LD_severity_mild',
#  'LD_severity_mild_atext',
#  'LD_severity_moderate',
#  'LD_severity_moderate_atext',
#  'LD_severity_profound_multiple',
#  'LD_severity_profound_multiple_atext',
#  'LD_severity_severe',
#  'LD_severity_severe_atext',
#  'Last_dental_check_inside_1_year',
#  'Last_dental_check_inside_1_year_atext',
#  'Last_dental_check_over_1_year',
#  'Last_dental_check_over_1_year_atext',
#  'Last_health_check_date',
#  'Last_health_check_date_atext',
#  'Last_health_check_never',
#  'Last_health_check_never_atext',
#  'Last_health_check_over_1_year',
#  'Last_health_check_over_1_year_atext',
#  'Last_health_check_within_1_month',
#  'Last_health_check_within_1_month_atext',
#  'Last_health_check_within_1_year',
#  'Last_health_check_within_1_year_atext',
#  'Last_health_check_within_3_months',
#  'Last_health_check_within_3_months_atext',
#  'Last_health_check_within_6_months',
#  'Last_health_check_within_6_months_atext',
#  'Last_meds_review',
#  'Last_meds_review_6_months',
#  'Last_meds_review_6_months_atext',
#  'Last_meds_review_atext',
#  'Last_meds_review_month',
#  'Last_meds_review_month_atext',
#  'Last_meds_review_over_year',
#  'Last_meds_review_over_year_atext',
#  'Last_meds_review_quarter',
#  'Last_meds_review_quarter_atext',
#  'Last_meds_review_week',
#  'Last_meds_review_week_atext',
#  'Last_meds_review_year',
#  'Last_meds_review_year_atext',
#  'Last_risk_assessment_over_1_year',
#  'Last_risk_assessment_over_1_year_atext',
#  'Last_risk_assessment_within_1_month',
#  'Last_risk_assessment_within_1_month_atext',
#  'Last_risk_assessment_within_1_year',
#  'Last_risk_assessment_within_1_year_atext',
#  'Last_risk_assessment_within_3_months',
#  'Last_risk_assessment_within_3_months_atext',
#  'Last_risk_assessment_within_6_months',
#  'Last_risk_assessment_within_6_months_atext',
#  'Legal_involvement',
#  'Legal_involvement_atext',
#  'Limited_verbal_communication',
#  'Limited_verbal_communication_atext',
#  'Literacy_skills',
#  'Literacy_skills_atext',
#  'Literate',
#  'Literate_atext',
#  'Living_alone',
#  'Living_alone_atext',
#  'Living_alone_spouse_partner',
#  'Living_alone_spouse_partner_atext',
#  'Living_with_carer',
#  'Living_with_carer_atext',
#  'Living_with_friends',
#  'Living_with_friends_atext',
#  'Living_with_other_family',
#  'Living_with_other_family_atext',
#  'Living_with_other_residents',
#  'Living_with_other_residents_atext',
#  'Living_with_parent',
#  'Living_with_parent_atext',
#  'MCA_comment',
#  'MCA_comment_atext',
#  'MCA_comments',
#  'MCA_comments_atext',
#  'Medical_histories',
#  'Medical_histories_atext',
#  'Medical_intervention_details',
#  'Medical_intervention_details_atext',
#  'Medical_interventions',
#  'Medical_interventions_atext',
#  'Medications',
#  'Medications_atext',
#  'Meds_antidepressants',
#  'Meds_antidepressants_atext',
#  'Meds_antiepileptics',
#  'Meds_antiepileptics_atext',
#  'Meds_antipsychotics',
#  'Meds_antipsychotics_atext',
#  'Meds_anxiolytics',
#  'Meds_anxiolytics_atext',
#  'Meds_hypnotics',
#  'Meds_hypnotics_atext',
#  'Meds_non_opioid_analgesics',
#  'Meds_non_opioid_analgesics_atext',
#  'Meds_opioid_analgesics',
#  'Meds_opioid_analgesics_atext',
#  'Mental_health_other',
#  'Mental_health_other_atext',
#  'Mental_psychological_conditions',
#  'Mental_psychological_conditions_atext',
#  'Mobility',
#  'Mobility_atext',
#  'Mobility_some_support',
#  'Mobility_some_support_atext',
#  'Mobility_total_support',
#  'Mobility_total_support_atext',
#  'Most_recent_review_support',
#  'Most_recent_review_support_atext',
#  'Motor_impairement',
#  'Motor_impairement_atext',
#  'Motor_impairement_hand',
#  'Motor_impairement_hand_atext',
#  'Motor_impairment',
#  'Motor_impairment_atext',
#  'Motore_impairment_hand',
#  'Motore_impairment_hand_atext',
#  'N_ID',
#  'No_apparent_illness',
#  'No_apparent_illness_atext',
#  'No_teeth',
#  'No_teeth_atext',
#  'No_verbal_communication',
#  'No_verbal_communication_atext',
#  'Not_literate',
#  'Not_literate_atext',
#  'Number_private_occupants_3_to_5',
#  'Number_private_occupants_3_to_5_atext',
#  'Nursing_CLDT_nurse',
#  'Nursing_CLDT_nurse_atext',
#  'Nursing_GP_practice_nurse',
#  'Nursing_GP_practice_nurse_atext',
#  'Nursing_LD_liaison_nurse',
#  'Nursing_LD_liaison_nurse_atext',
#  'Nursing_LD_specialist',
#  'Nursing_LD_specialist_atext',
#  'Nursing_PEG_nurse',
#  'Nursing_PEG_nurse_atext',
#  'Nursing_cardiac_nurse',
#  'Nursing_cardiac_nurse_atext',
#  'Nursing_community_matron',
#  'Nursing_community_matron_atext',
#  'Nursing_community_nurse',
#  'Nursing_community_nurse_atext',
#  'Nursing_community_palliative_nurse',
#  'Nursing_community_palliative_nurse_atext',
#  'Nursing_community_psychiatric_nurse',
#  'Nursing_community_psychiatric_nurse_atext',
#  'Nursing_community_services',
#  'Nursing_community_services_atext',
#  'Nursing_continence_nurse',
#  'Nursing_continence_nurse_atext',
#  'Nursing_dementia_nurse',
#  'Nursing_dementia_nurse_atext',
#  'Nursing_diabetes_nurse',
#  'Nursing_diabetes_nurse_atext',
#  'Nursing_district_nurse',
#  'Nursing_district_nurse_atext',
#  'Nursing_epilepsy_nurse',
#  'Nursing_epilepsy_nurse_atext',
#  'Nursing_for_end_of_life',
#  'Nursing_for_end_of_life_atext',
#  'Nursing_home',
#  'Nursing_home_LD',
#  'Nursing_home_LD_atext',
#  'Nursing_home_atext',
#  'Nursing_home_dementia',
#  'Nursing_home_dementia_atext',
#  'Nursing_home_generic',
#  'Nursing_home_generic_atext',
#  'Nursing_home_some_LD',
#  'Nursing_home_some_LD_atext',
#  'Nursing_hospice',
#  'Nursing_hospice_atext',
#  'Nursing_hospital_liaison_nurse',
#  'Nursing_hospital_liaison_nurse_atext',
#  'Nursing_hospital_palliative_nurse',
#  'Nursing_hospital_palliative_nurse_atext',
#  'Nursing_non_LD_specialist',
#  'Nursing_non_LD_specialist_atext',
#  'Nursing_primary_care',
#  'Nursing_primary_care_atext',
#  'Nursing_respiratory_nurse',
#  'Nursing_respiratory_nurse_atext',
#  'Nursing_stroke_nurse',
#  'Nursing_stroke_nurse_atext',
#  'Nursing_tissue_viability_nurse',
#  'Nursing_tissue_viability_nurse_atext',
#  'On_LD_register',
#  'On_LD_register_atext',
#  'On_LD_register_no',
#  'On_LD_register_no_atext',
#  'On_LD_register_yes',
#  'On_LD_register_yes_atext',
#  'Other_private_residence',
#  'Other_private_residence_atext',
#  'Other_safeguarding_referral',
#  'Other_safeguarding_referral_atext',
#  'Other_sensory_impairment',
#  'Other_sensory_impairment_atext',
#  'Own_home',
#  'Own_home_atext',
#  'PT_paid',
#  'PT_paid_atext',
#  'PT_voluntary',
#  'PT_voluntary_atext',
#  'Paid_carer_agency',
#  'Paid_carer_agency_atext',
#  'Pain_assessment',
#  'Pain_assessment_atext',
#  'Pain_assessment_no',
#  'Pain_assessment_no_atext',
#  'Pain_assessment_yes',
#  'Pain_assessment_yes_atext',
#  'Pain_issues',
#  'Pain_issues_atext',
#  'Pain_long_term',
#  'Pain_long_term_atext',
#  'Pain_unresolved',
#  'Pain_unresolved_atext',
#  'Parental_home',
#  'Parental_home_atext',
#  'Parents',
#  'Parents_atext',
#  'Patient_engagement',
#  'Patient_engagement_atext',
#  'Patient_involved_in_decisions',
#  'Patient_involved_in_decisions_atext',
#  'Patient_missed_appointment',
#  'Patient_missed_appointment_atext',
#  'Patients_family_brought_in',
#  'Patients_family_brought_in_atext',
#  'Person_refused_treatment',
#  'Person_refused_treatment_atext',
#  'Personal_healthcare',
#  'Personal_healthcare_atext',
#  'Personal_healthcare_full_support',
#  'Personal_healthcare_full_support_atext',
#  'Personal_healthcare_independent',
#  'Personal_healthcare_independent_atext',
#  'Personal_healthcare_some_support',
#  'Personal_healthcare_some_support_atext',
#  'Persons_family_brought_in',
#  'Persons_family_brought_in_atext',
#  'Poor_practice',
#  'Poor_practice_EOL',
#  'Poor_practice_EOL_atext',
#  'Poor_practice_MCA',
#  'Poor_practice_MCA_atext',
#  'Poor_practice_atext',
#  'Poor_practice_care_coordination',
#  'Poor_practice_care_coordination_atext',
#  'Poor_practice_care_provider',
#  'Poor_practice_care_provider_atext',
#  'Poor_practice_primary',
#  'Poor_practice_primary_atext',
#  'Poor_practice_review',
#  'Poor_practice_review_atext',
#  'Poor_practice_secondary',
#  'Poor_practice_secondary_atext',
#  'Poor_practice_transition',
#  'Poor_practice_transition_atext',
#  'Posture_needs',
#  'Posture_needs_atext',
#  'Pressure_sores',
#  'Pressure_sores_atext',
#  'Previous_hospital_admissions',
#  'Previous_hospital_admissions_atext',
#  'Previous_pregnancy',
#  'Previous_pregnancy_atext',
#  'Prof_CAMHS',
#  'Prof_CAMHS_atext',
#  'Prof_CLDT',
#  'Prof_CLDT_atext',
#  'Prof_GP_no',
#  'Prof_GP_no_atext',
#  'Prof_LD_nurse',
#  'Prof_LD_nurse_atext',
#  'Prof_SALT',
#  'Prof_SALT_LD',
#  'Prof_SALT_LD_atext',
#  'Prof_SALT_atext',
#  'Prof_SALT_generic',
#  'Prof_SALT_generic_atext',
#  'Prof_art_music_drama_therapist',
#  'Prof_art_music_drama_therapist_atext',
#  'Prof_cardiologist',
#  'Prof_cardiologist_atext',
#  'Prof_care_home_carer_LD',
#  'Prof_care_home_carer_LD_atext',
#  'Prof_care_home_carer_generic',
#  'Prof_care_home_carer_generic_atext',
#  'Prof_dietician',
#  'Prof_dietician_atext',
#  'Prof_direct_payment_brokers',
#  'Prof_direct_payment_brokers_atext',
#  'Prof_gastroenterologist',
#  'Prof_gastroenterologist_atext',
#  'Prof_gynaecologist',
#  'Prof_gynaecologist_atext',
#  'Prof_neurologist',
#  'Prof_neurologist_atext',
#  'Prof_nursing_home_carer_LD',
#  'Prof_nursing_home_carer_LD_atext',
#  'Prof_nursing_home_carer_generic',
#  'Prof_nursing_home_carer_generic_atext',
#  'Prof_occupational_therapist',
#  'Prof_occupational_therapist_LD',
#  'Prof_occupational_therapist_LD_atext',
#  'Prof_occupational_therapist_atext',
#  'Prof_occupational_therapist_generic',
#  'Prof_occupational_therapist_generic_atext',
#  'Prof_oncologist',
#  'Prof_oncologist_atext',
#  'Prof_orthotist_podiatrist',
#  'Prof_orthotist_podiatrist_atext',
#  'Prof_paediatrician',
#  'Prof_paediatrician_atext',
#  'Prof_physiotherapist',
#  'Prof_physiotherapist_LD',
#  'Prof_physiotherapist_LD_atext',
#  'Prof_physiotherapist_atext',
#  'Prof_physiotherapist_generic',
#  'Prof_physiotherapist_generic_atext',
#  'Prof_podiatrist',
#  'Prof_podiatrist_atext',
#  'Prof_psychiatrist',
#  'Prof_psychiatrist_LD',
#  'Prof_psychiatrist_LD_atext',
#  'Prof_psychiatrist_atext',
#  'Prof_psychiatrist_generic',
#  'Prof_psychiatrist_generic_atext',
#  'Prof_psychologist',
#  'Prof_psychologist_LD',
#  'Prof_psychologist_LD_atext',
#  'Prof_psychologist_atext',
#  'Prof_psychologist_generic',
#  'Prof_psychologist_generic_atext',
#  'Prof_renal_specialist',
#  'Prof_renal_specialist_atext',
#  'Prof_rheumatologist',
#  'Prof_rheumatologist_atext',
#  'Prof_supported_living_carer_LD',
#  'Prof_supported_living_carer_LD_atext',
#  'Prof_surgeon',
#  'Prof_surgeon_atext',
#  'Prof_urologist',
#  'Prof_urologist_atext',
#  'Professional_IMCA',
#  'Professional_IMCA_atext',
#  'Professional_health_medical_support',
#  'Professional_health_medical_support_atext',
#  'Professional_health_nursing_support',
#  'Professional_health_nursing_support_atext',
#  'Professional_health_support_LD_services',
#  'Professional_health_support_LD_services_atext',
#  'Professional_health_support_allied',
#  'Professional_health_support_allied_atext',
#  'Professional_health_support_primary',
#  'Professional_health_support_primary_atext',
#  'Professional_health_support_secondary',
#  'Professional_health_support_secondary_atext',
#  'Professional_home_support',
#  'Professional_home_support_atext',
#  'Professional_private_agencies',
#  'Professional_private_agencies_atext',
#  'Professional_support_CLDT',
#  'Professional_support_CLDT_atext',
#  'Professional_support_advocacy',
#  'Professional_support_advocacy_atext',
#  'Professional_support_concerns',
#  'Professional_support_concerns_atext',
#  'Professional_support_concerns_no',
#  'Professional_support_concerns_no_atext',
#  'Professional_support_concerns_yes',
#  'Professional_support_concerns_yes_atext',
#  'Professional_support_frequency',
#  'Professional_support_frequency_atext',
#  'Professional_support_hospice_EOL',
#  'Professional_support_hospice_EOL_atext',
#  'Professional_support_local_authority',
#  'Professional_support_local_authority_atext',
#  'Professional_support_voluntary',
#  'Professional_support_voluntary_atext',
#  'Professionals_correct_followup_no',
#  'Professionals_correct_followup_no_atext',
#  'Professionals_correct_followup_yes',
#  'Professionals_correct_followup_yes_atext',
#  'Professionals_giving_correct_treatment_no',
#  'Professionals_giving_correct_treatment_no_atext',
#  'Professionals_instructions_why_not',
#  'Professionals_instructions_why_not_atext',
#  'Psychosis',
#  'Psychosis_atext',
#  'Public_protection_plan',
#  'Public_protection_plan_atext',
#  'Reasonable_adjustments',
#  'Reasonable_adjustments_atext',
#  'Reasonable_adjustments_communication_aids',
#  'Reasonable_adjustments_communication_aids_atext',
#  'Reasonable_adjustments_desired',
#  'Reasonable_adjustments_desired_a_quiet_space',
#  'Reasonable_adjustments_desired_a_quiet_space_atext',
#  'Reasonable_adjustments_desired_atext',
#  'Reasonable_adjustments_desired_communication_aids',
#  'Reasonable_adjustments_desired_communication_aids_atext',
#  'Reasonable_adjustments_desired_flexibility_on_appts',
#  'Reasonable_adjustments_desired_flexibility_on_appts_atext',
#  'Reasonable_adjustments_desired_helpers_in_hospital',
#  'Reasonable_adjustments_desired_helpers_in_hospital_atext',
#  'Reasonable_adjustments_desired_home_visit',
#  'Reasonable_adjustments_desired_home_visit_atext',
#  'Reasonable_adjustments_desired_other',
#  'Reasonable_adjustments_desired_other_atext',
#  'Reasonable_adjustments_flexibility_on_appts',
#  'Reasonable_adjustments_flexibility_on_appts_atext',
#  'Reasonable_adjustments_helpers_in_hospital',
#  'Reasonable_adjustments_helpers_in_hospital_atext',
#  'Reasonable_adjustments_home_visit',
#  'Reasonable_adjustments_home_visit_atext',
#  'Reasonable_adjustments_made',
#  'Reasonable_adjustments_made_a_quiet_space',
#  'Reasonable_adjustments_made_a_quiet_space_atext',
#  'Reasonable_adjustments_made_atext',
#  'Reasonable_adjustments_made_communication_aids',
#  'Reasonable_adjustments_made_communication_aids_atext',
#  'Reasonable_adjustments_made_flexibility_on_appts',
#  'Reasonable_adjustments_made_flexibility_on_appts_atext',
#  'Reasonable_adjustments_made_helpers_in_hospital',
#  'Reasonable_adjustments_made_helpers_in_hospital_atext',
#  'Reasonable_adjustments_made_home_visit',
#  ...]

# %% [raw]
# normal_df[normal_df.N_ID=='25210492']

# %% [markdown]
# # List of Downs people for Rachel

# %%
downs_ids = normal_df[normal_df.Clinical_downs==1].N_ID
downs_ids.to_csv('downs_ids.csv',index=False)

# %%
mels_list = pd.read_csv('mels_nids.csv',dtype={'nid':str})
print(mels_list.tail())
# Out:
#          nid
# 31  25287401
# 32  25290145
# 33  25296025
# 34  25297187
# 35  23293351

# %%
pd.merge(mels_list,normal_df,left_on='nid',right_on='N_ID',how='left')[['N_ID','coder_atext']]
# Out:
#         N_ID coder_atext
# 0   20298380        nick
# 1   20972552        nick
# 2   23041548         ann
# 3   25130552       karen
# 4   25150712       karen
# 5   25151846        nick
# 6   25163151       karen
# 7        NaN         NaN
# 8   25191732      kamila
# 9   25198851       karen
# 10  25210191        nick
# 11  25217765      kamila
# 12  25220439        nick
# 13  25222238        nick
# 14  25225605        nick
# 15  25230085       karen
# 16  25235538      kamila
# 17  25236098      kamila
# 18  25245212         ann
# 19  25246731        nick
# 20  25248712      kamila
# 21  25249699        nick
# 22  25250147      kamila
# 23  25255152      kamila
# 24  25274045         ann
# 25  25278378      kamila
# 26  25287345      kamila
# 27  25289788       karen
# 28  25291958        nick
# 29  23063409         ann
# 30  23720564         ann
# 31  25287401       karen
# 32  25290145       karen
# 33  25296025       karen
# 34  25297187       karen
# 35  23293351        nick

# %%
normal_df_sorted = normal_df.sort_values(['N_ID','number_codes'])
# get last in any list of same IDs to select the review with most codes if any were coded by 2 or more team
normal_df_no_dups = normal_df_sorted.groupby('N_ID').last().reset_index()

# %%
len(normal_df_no_dups)
# Out:
# 1372

# %%
# save this final df to text file for SPSS use
normal_df_no_dups.to_csv('normal_nvivo_df_spss.txt',index=False,sep='\t')

# %%
index_of_big_cell = normal_df_no_dups[normal_df_no_dups['Medical_histories_atext'].str.len()>32750].index.values[0]
big_cell_text = normal_df_no_dups[normal_df_no_dups['Medical_histories_atext'].str.len()>32750].Medical_histories_atext.values[0]

# %%
index_of_big_cell
normal_df_no_dups.loc[index_of_big_cell,'Medical_histories_atext'] = big_cell_text[:32760]

# %%
# generate spss syntax file to load nvivo data into spss
# what are the variables?
# if variable ends with '_atext' then get length and set to string

# edited 30/5/19 to ensure that SPSS maximum length of string variable (32767 chars) is not exceeded

required_columns =  list(normal_df_no_dups.columns)
spps_syntax_for_normal_nvivo_vars = ''
for var in required_columns:
    if var.endswith('_atext'):
        print(var)
        max_text_length = str(int(normal_df_no_dups[var].str.len().max()))
        print('max = ',max_text_length)
        spps_syntax_for_normal_nvivo_vars = spps_syntax_for_normal_nvivo_vars + var + '  A' + max_text_length + '  \n'
    else:
        spps_syntax_for_normal_nvivo_vars = spps_syntax_for_normal_nvivo_vars + var +' F3.1  \n'
        
print(spps_syntax_for_normal_nvivo_vars)
# Out:
# AAA_screening_atext
# max =  69
# AAA_screening_no_atext
# max =  197
# AAA_screening_yes_atext
# max =  52
# AP_agencies_atext
# max =  4462
# AP_completed_DNACPR_atext
# max =  387
# AP_completed_EOL_care_atext
# max =  655
# AP_completed_LD_awareness_atext
# max =  1268
# AP_completed_MCA_atext
# max =  1069
# AP_completed_agencies_atext
# max =  2289
# AP_completed_care_coordination_atext
# max =  1123
# AP_completed_documentation_atext
# max =  1071
# AP_completed_family_atext
# max =  0
# AP_completed_other_atext
# max =  1693
# AP_completed_reasonable_adjustments_atext
# max =  1221
# AP_completed_role_paid_carers_atext
# max =  1076
# AP_person_atext
# max =  1136
# AP_raised_DNACPR_atext
# max =  1374
# AP_raised_EOL_care_atext
# max =  2379
# AP_raised_LD_awareness_atext
# max =  4064
# AP_raised_MCA_atext
# max =  4327
# AP_raised_agencies_atext
# max =  8946
# AP_raised_care_coordination_atext
# max =  3718
# AP_raised_documentation_atext
# max =  2003
# AP_raised_family_atext
# max =  1821
# AP_raised_other_atext
# max =  3519
# AP_raised_reasonable_adjustments_atext
# max =  2915
# AP_raised_role_paid_carers_atext
# max =  1821
# Absences_1_to_4_per_month_atext
# max =  684
# Absences_frequency_atext
# max =  642
# Accident_incident_atext
# max =  596
# Accommodation_atext
# max =  490
# Accommodation_type_atext
# max =  274
# Acm_Change_1Yr_Num_atext
# max =  2100
# Acm_Change_1Yr_one_atext
# max =  2100
# Acm_Change_1Yr_over_three_atext
# max =  44
# Acm_Change_1Yr_three_atext
# max =  774
# Acm_Change_1Yr_two_atext
# max =  576
# Acm_Iss_1Yr_atext
# max =  2801
# Acm_Iss_Evr_atext
# max =  1860
# Acm_Multi_Changes_atext
# max =  664
# Acm_TOD_5years_and_more_atext
# max =  934
# Acm_TOD_dur_LT_10years_atext
# max =  207
# Acm_TOD_dur_LT_1month_atext
# max =  625
# Acm_TOD_dur_LT_1year_atext
# max =  475
# Acm_TOD_dur_LT_5years_atext
# max =  858
# Acm_TOD_dur_cat_atext
# max =  934
# Acm_change_reas_acm_atext
# max =  349
# Acm_change_reas_better_accom_atext
# max =  586
# Acm_change_reas_closure_atext
# max =  1245
# Acm_change_reas_pers_condition_atext
# max =  2100
# Acm_change_reas_unknown_atext
# max =  447
# Acm_change_reason_cat_atext
# max =  2100
# Acm_hist_institution_atext
# max =  756
# Acm_number_occupants_atext
# max =  391
# Action_points_raised_atext
# max =  902
# Activities_atext
# max =  869
# Adopted_atext
# max =  564
# Advocate_atext
# max =  554
# Advocate_no_atext
# max =  851
# Advocate_yes_atext
# max =  2018
# Agency_safeguarding_referral_atext
# max =  10575
# Alcohol_misuse_atext
# max =  473
# Alcohol_misuse_in_past_atext
# max =  778
# Alcohol_misuse_yes_atext
# max =  2176
# Allergies_atext
# max =  775
# Anxiety_atext
# max =  1891
# Any_aids_employed_atext
# max =  3970
# Appointment_cancelled_atext
# max =  1268
# Aspiration_before_last_year_atext
# max =  858
# Aspiration_never_atext
# max =  72
# Aspiration_unknown_atext
# max =  588
# Aspiration_within_last_year_atext
# max =  2624
# Austism_no_atext
# max =  19
# Autism_adult_diagnosis_atext
# max =  1048
# Autism_childhood_diagnosis_atext
# max =  1306
# BMI_atext
# max =  547
# Behaviour_problems_atext
# max =  17056
# Best_practice_atext
# max =  6137
# Bipolar_atext
# max =  2968
# Blood_pressure_high_atext
# max =  1242
# Blood_pressure_low_atext
# max =  1102
# Bowel_cancer_screening_atext
# max =  327
# Bowel_cancer_screening_no_atext
# max =  434
# Bowel_cancer_screening_yes_atext
# max =  474
# Breast_cancer_screening_atext
# max =  1472
# Breast_cancer_screening_no_atext
# max =  445
# Breast_cancer_screening_yes_atext
# max =  708
# CF_care_coordination_atext
# max =  458
# CF_care_provision_atext
# max =  4037
# CF_care_training_need_atext
# max =  458
# CF_family_or_environment_atext
# max =  1990
# CF_healthcare_delay_diagnosis_atext
# max =  1639
# CF_healthcare_delay_primary_atext
# max =  121
# CF_healthcare_delay_treatment_atext
# max =  241
# CF_pers_mental_health_atext
# max =  177
# CF_pers_self_harm_atext
# max =  43
# CF_person_atext
# max =  2008
# CF_service_provision_atext
# max =  5567
# Cancer_atext
# max =  3923
# Cancer_date_referral_atext
# max =  1230
# Cancer_date_symptoms_noticed_atext
# max =  1901
# Cancer_date_symptoms_reported_atext
# max =  2112
# Cancer_investigations_atext
# max =  1851
# Cancer_investigations_before_referral_atext
# max =  225
# Cancer_investigations_ordered_atext
# max =  3856
# Cancer_main_symptom_atext
# max =  3371
# Cancer_spread_metastasis_atext
# max =  2260
# Cancer_stage_2_atext
# max =  162
# Cancer_stage_3_atext
# max =  214
# Cancer_stage_4_atext
# max =  1013
# Cancer_stage_atext
# max =  477
# Cancer_symptoms_reported_to_atext
# max =  127
# Care_plan_EOL_atext
# max =  6813
# Care_plan_dementia_atext
# max =  904
# Care_plan_diabetes_atext
# max =  1234
# Care_plan_epilepsy_atext
# max =  1485
# Care_plan_other_atext
# max =  5027
# Care_plans_atext
# max =  1847
# Cervical_cancer_screening_atext
# max =  956
# Cervical_cancer_screening_no_atext
# max =  464
# Cervical_cancer_screening_yes_atext
# max =  242
# Child_in_need_atext
# max =  267
# Choking_before_last_year_atext
# max =  875
# Choking_never_atext
# max =  496
# Choking_unknown_atext
# max =  293
# Choking_within_last_year_atext
# max =  1730
# Circumstances_of_death_atext
# max =  8062
# Clinical_COPD_atext
# max =  1531
# Clinical_DVT_atext
# max =  1309
# Clinical_UTI_atext
# max =  4395
# Clinical_asthma_atext
# max =  1735
# Clinical_autism_atext
# max =  1721
# Clinical_blood_pressure_atext
# max =  531
# Clinical_cardiovascular_problem_atext
# max =  5049
# Clinical_cerebral_palsy_atext
# max =  594
# Clinical_condition_atext
# max =  14149
# Clinical_continence_atext
# max =  944
# Clinical_degenerative_condition_atext
# max =  1582
# Clinical_dementia_atext
# max =  3988
# Clinical_diabetes_atext
# max =  2247
# Clinical_double_incontinence_atext
# max =  1307
# Clinical_downs_atext
# max =  1314
# Clinical_feacal_incontinence_atext
# max =  1255
# Clinical_genetic_condition_atext
# max =  1649
# Clinical_high_cholesterol_atext
# max =  566
# Clinical_history_chest_infections_atext
# max =  3175
# Clinical_history_falls_atext
# max =  2963
# Clinical_kidney_problems_atext
# max =  5035
# Clinical_osteoporisis_atext
# max =  898
# Clinical_pneumonia_aspiration_atext
# max =  2632
# Clinical_pneumonia_infectious_atext
# max =  1599
# Clinical_prostate_problems_atext
# max =  1076
# Clinical_sepsis_atext
# max =  1020
# Clinical_urinary_incontinent_atext
# max =  833
# Communication_abilities_atext
# max =  1493
# Constipation_atext
# max =  3129
# Continence_aids_atext
# max =  1417
# Contraception_atext
# max =  1011
# Contributory_factor_COD_atext
# max =  371
# DNACPR_atext
# max =  713
# DNACPR_comments_atext
# max =  8263
# Daytime_activities_atext
# max =  204
# Daytime_independent_activities_atext
# max =  702
# Death_from_fall_atext
# max =  63
# Death_from_other_accidents_atext
# max =  1803
# Death_from_road_accident_atext
# max =  1019
# Death_from_suicide_atext
# max =  4752
# Dental_issues_atext
# max =  2167
# Dental_last_check_atext
# max =  140
# Dental_last_check_date_atext
# max =  141
# Dental_regular_care_atext
# max =  602
# Depression_atext
# max =  1858
# Diabetes_type_1_atext
# max =  5242
# Diabetes_type_2_atext
# max =  4490
# Diabetes_type_unspecified_atext
# max =  3437
# Difficulties_services_with_carer_atext
# max =  1806
# Domestic_violence_household_atext
# max =  701
# Drug_misuse_atext
# max =  331
# Drug_misuse_in_past_atext
# max =  345
# Drug_misuse_yes_atext
# max =  798
# Eating_disorder_atext
# max =  613
# Employment_at_TOD_atext
# max =  116
# Employment_atext
# max =  553
# Employment_ever_no_atext
# max =  291
# Employment_ever_yes_atext
# max =  468
# Employment_paid_ever_atext
# max =  244
# Epi_care_plan_atext
# max =  139
# Epi_frequecy_duration_atext
# max =  654
# Epi_manage_descr_atext
# max =  5978
# Epilepsy_atext
# max =  3988
# Event_of_death_issues_atext
# max =  179
# Fam_carers_supported_atext
# max =  482
# Fam_carers_supported_no_atext
# max =  968
# Fam_carers_supported_yes_atext
# max =  2871
# Fam_contact_child_atext
# max =  456
# Fam_contact_dail1y_atext
# max =  144
# Fam_contact_few_times_yearly_atext
# max =  221
# Fam_contact_frequently_atext
# max =  1230
# Fam_contact_infrequently_atext
# max =  1048
# Fam_contact_less_than_yearly_atext
# max =  282
# Fam_contact_monthly_atext
# max =  468
# Fam_contact_never_atext
# max =  1021
# Fam_contact_other_atext
# max =  954
# Fam_contact_parent_atext
# max =  395
# Fam_contact_sibling_atext
# max =  413
# Fam_contact_unspecified_atext
# max =  179
# Fam_contact_weekly_atext
# max =  227
# Fam_listened_to_no_atext
# max =  2712
# Fam_listened_to_yes_atext
# max =  1370
# Fam_rel_concerns_atext
# max =  1294
# Fam_rel_poor_atext
# max =  3718
# Fam_rel_seemed_good_atext
# max =  1626
# Fam_rel_unknown_atext
# max =  344
# Families_listened_to_atext
# max =  503
# Family_carers_atext
# max =  1478
# Family_carers_no_atext
# max =  651
# Family_carers_views_of_death_atext
# max =  6764
# Family_carers_yes_atext
# max =  1478
# Family_concerns_about_death_atext
# max =  2550
# Family_contact_regularity_atext
# max =  539
# Family_contacts_members_atext
# max =  197
# Family_relationships_atext
# max =  777
# Family_relative_deceased_atext
# max =  1054
# Family_safeguarding_referral_atext
# max =  2953
# Fear_of_doctor_or_treatment_atext
# max =  1767
# Fear_of_doctor_sensitization_atext
# max =  1044
# Fiinancial_abuse_atext
# max =  1860
# Financial_abuse_atext
# max =  4974
# Financial_circumstances_atext
# max =  4845
# Good_practice_EOL_atext
# max =  3470
# Good_practice_MCA_atext
# max =  3444
# Good_practice_atext
# max =  2694
# Good_practice_care_coordination_atext
# max =  3167
# Good_practice_care_provider_atext
# max =  3587
# Good_practice_primary_atext
# max =  3642
# Good_practice_review_atext
# max =  5395
# Good_practice_secondary_atext
# max =  3087
# Good_practice_transition_atext
# max =  882
# Good_verbal_communication_atext
# max =  1758
# Health_action_plan_atext
# max =  1108
# Health_action_plan_no_atext
# max =  473
# Health_action_plan_yes_atext
# max =  4929
# Health_atext
# max =  2052
# Health_checks_annual_LD_atext
# max =  503
# Health_checks_anual_LD_atext
# max =  1011
# Health_checks_atext
# max =  829
# Healthcare_institutions_processes_atext
# max =  1406
# Hearing_problems_atext
# max =  167
# Hearing_problems_no_atext
# max =  425
# Hearing_problems_yes_atext
# max =  915
# Height_atext
# max =  40
# Height_weight_BMI_atext
# max =  547
# Holidays_atext
# max =  1356
# Hospice_atext
# max =  1251
# Hospital_communication_document_atext
# max =  800
# Hospital_communication_document_no_atext
# max =  542
# Hospital_communication_document_yes_atext
# max =  927
# Housing_provider_atext
# max =  1226
# Immunised_against_flu_atext
# max =  250
# Immunised_against_flu_no_atext
# max =  728
# Immunised_against_flu_yes_atext
# max =  731
# Independently_mobile_atext
# max =  662
# Informal_supp_family_other_house_atext
# max =  744
# Informal_supp_friends_other_house_atext
# max =  1881
# Informal_supp_friends_same_house_atext
# max =  703
# Informal_support_atext
# max =  387
# Institution_long_stay_hospital_atext
# max =  334
# Interpersonal_relationships_atext
# max =  1350
# Issues_agencies_atext
# max =  19598
# Issues_atext
# max =  4960
# Issues_family_atext
# max =  18399
# Issues_person_atext
# max =  8095
# Known_to_police_atext
# max =  1135
# Known_to_police_in_past_atext
# max =  1860
# Known_to_police_yes_atext
# max =  4599
# LA_childrens_social_services_atext
# max =  288
# LA_education_atext
# max =  856
# LA_support_day_services_LD_atext
# max =  466
# LA_support_day_services_generic_atext
# max =  1933
# LA_support_respite_atext
# max =  2578
# LA_support_social_worker_CLDT_atext
# max =  2089
# LA_support_social_worker_generic_atext
# max =  8901
# LA_support_worker_atext
# max =  6404
# LD_severity_atext
# max =  893
# LD_severity_mild_atext
# max =  382
# LD_severity_moderate_atext
# max =  342
# LD_severity_profound_multiple_atext
# max =  301
# LD_severity_severe_atext
# max =  504
# Last_dental_check_inside_1_year_atext
# max =  456
# Last_dental_check_over_1_year_atext
# max =  164
# Last_health_check_date_atext
# max =  654
# Last_health_check_never_atext
# max =  50
# Last_health_check_over_1_year_atext
# max =  738
# Last_health_check_within_1_month_atext
# max =  217
# Last_health_check_within_1_year_atext
# max =  6829
# Last_health_check_within_3_months_atext
# max =  423
# Last_health_check_within_6_months_atext
# max =  120
# Last_meds_review_6_months_atext
# max =  897
# Last_meds_review_atext
# max =  734
# Last_meds_review_month_atext
# max =  716
# Last_meds_review_over_year_atext
# max =  654
# Last_meds_review_quarter_atext
# max =  657
# Last_meds_review_week_atext
# max =  665
# Last_meds_review_year_atext
# max =  386
# Last_risk_assessment_over_1_year_atext
# max =  428
# Last_risk_assessment_within_1_month_atext
# max =  737
# Last_risk_assessment_within_1_year_atext
# max =  649
# Last_risk_assessment_within_3_months_atext
# max =  1160
# Last_risk_assessment_within_6_months_atext
# max =  1005
# Legal_involvement_atext
# max =  3198
# Limited_verbal_communication_atext
# max =  1026
# Literacy_skills_atext
# max =  241
# Literate_atext
# max =  554
# Living_alone_atext
# max =  652
# Living_alone_spouse_partner_atext
# max =  1099
# Living_with_carer_atext
# max =  481
# Living_with_friends_atext
# max =  328
# Living_with_other_family_atext
# max =  725
# Living_with_other_residents_atext
# max =  855
# Living_with_parent_atext
# max =  694
# MCA_comment_atext
# max =  132
# MCA_comments_atext
# max =  12644
# Medical_histories_atext
# max =  32760
# Medical_intervention_details_atext
# max =  17258
# Medical_interventions_atext
# max =  8138
# Medications_atext
# max =  12040
# Meds_antidepressants_atext
# max =  1001
# Meds_antiepileptics_atext
# max =  1642
# Meds_antipsychotics_atext
# max =  1588
# Meds_anxiolytics_atext
# max =  961
# Meds_hypnotics_atext
# max =  293
# Meds_non_opioid_analgesics_atext
# max =  213
# Meds_opioid_analgesics_atext
# max =  222
# Mental_health_other_atext
# max =  1479
# Mental_psychological_conditions_atext
# max =  2048
# Mobility_atext
# max =  1768
# Mobility_some_support_atext
# max =  1443
# Mobility_total_support_atext
# max =  1488
# Most_recent_review_support_atext
# max =  2136
# Motor_impairement_atext
# max =  1614
# Motor_impairement_hand_atext
# max =  1171
# Motor_impairment_atext
# max =  395
# Motore_impairment_hand_atext
# max =  658
# No_apparent_illness_atext
# max =  3665
# No_teeth_atext
# max =  82
# No_verbal_communication_atext
# max =  1072
# Not_literate_atext
# max =  259
# Number_private_occupants_3_to_5_atext
# max =  58
# Nursing_CLDT_nurse_atext
# max =  29668
# Nursing_GP_practice_nurse_atext
# max =  3573
# Nursing_LD_liaison_nurse_atext
# max =  4009
# Nursing_LD_specialist_atext
# max =  3066
# Nursing_PEG_nurse_atext
# max =  305
# Nursing_cardiac_nurse_atext
# max =  282
# Nursing_community_matron_atext
# max =  1127
# Nursing_community_nurse_atext
# max =  2152
# Nursing_community_palliative_nurse_atext
# max =  1686
# Nursing_community_psychiatric_nurse_atext
# max =  1200
# Nursing_community_services_atext
# max =  995
# Nursing_continence_nurse_atext
# max =  403
# Nursing_dementia_nurse_atext
# max =  1536
# Nursing_diabetes_nurse_atext
# max =  3228
# Nursing_district_nurse_atext
# max =  9107
# Nursing_epilepsy_nurse_atext
# max =  2095
# Nursing_for_end_of_life_atext
# max =  1987
# Nursing_home_LD_atext
# max =  262
# Nursing_home_atext
# max =  1041
# Nursing_home_dementia_atext
# max =  495
# Nursing_home_generic_atext
# max =  816
# Nursing_home_some_LD_atext
# max =  624
# Nursing_hospice_atext
# max =  1514
# Nursing_hospital_liaison_nurse_atext
# max =  3717
# Nursing_hospital_palliative_nurse_atext
# max =  2294
# Nursing_non_LD_specialist_atext
# max =  833
# Nursing_primary_care_atext
# max =  1400
# Nursing_respiratory_nurse_atext
# max =  415
# Nursing_stroke_nurse_atext
# max =  199
# Nursing_tissue_viability_nurse_atext
# max =  9893
# On_LD_register_atext
# max =  452
# On_LD_register_no_atext
# max =  746
# On_LD_register_yes_atext
# max =  457
# Other_private_residence_atext
# max =  609
# Other_safeguarding_referral_atext
# max =  5053
# Other_sensory_impairment_atext
# max =  332
# Own_home_atext
# max =  664
# PT_paid_atext
# max =  149
# PT_voluntary_atext
# max =  245
# Paid_carer_agency_atext
# max =  15
# Pain_assessment_atext
# max =  1530
# Pain_assessment_no_atext
# max =  435
# Pain_assessment_yes_atext
# max =  1032
# Pain_issues_atext
# max =  1728
# Pain_long_term_atext
# max =  2408
# Pain_unresolved_atext
# max =  491
# Parental_home_atext
# max =  708
# Parents_atext
# max =  224
# Patient_engagement_atext
# max =  3068
# Patient_involved_in_decisions_atext
# max =  2589
# Patient_missed_appointment_atext
# max =  3252
# Patients_family_brought_in_atext
# max =  3523
# Person_refused_treatment_atext
# max =  3120
# Personal_healthcare_atext
# max =  996
# Personal_healthcare_full_support_atext
# max =  1512
# Personal_healthcare_independent_atext
# max =  673
# Personal_healthcare_some_support_atext
# max =  2287
# Persons_family_brought_in_atext
# max =  1365
# Poor_practice_EOL_atext
# max =  2761
# Poor_practice_MCA_atext
# max =  3609
# Poor_practice_atext
# max =  2709
# Poor_practice_care_coordination_atext
# max =  8285
# Poor_practice_care_provider_atext
# max =  11472
# Poor_practice_primary_atext
# max =  3342
# Poor_practice_review_atext
# max =  837
# Poor_practice_secondary_atext
# max =  6156
# Poor_practice_transition_atext
# max =  1856
# Posture_needs_atext
# max =  3794
# Pressure_sores_atext
# max =  6410
# Previous_hospital_admissions_atext
# max =  7250
# Previous_pregnancy_atext
# max =  562
# Prof_CAMHS_atext
# max =  0
# Prof_CLDT_atext
# max =  9284
# Prof_GP_no_atext
# max =  168
# Prof_LD_nurse_atext
# max =  957
# Prof_SALT_LD_atext
# max =  926
# Prof_SALT_atext
# max =  10843
# Prof_SALT_generic_atext
# max =  1220
# Prof_art_music_drama_therapist_atext
# max =  321
# Prof_cardiologist_atext
# max =  2361
# Prof_care_home_carer_LD_atext
# max =  1023
# Prof_care_home_carer_generic_atext
# max =  710
# Prof_dietician_atext
# max =  1438
# Prof_direct_payment_brokers_atext
# max =  596
# Prof_gastroenterologist_atext
# max =  2842
# Prof_gynaecologist_atext
# max =  1187
# Prof_neurologist_atext
# max =  3606
# Prof_nursing_home_carer_LD_atext
# max =  288
# Prof_nursing_home_carer_generic_atext
# max =  497
# Prof_occupational_therapist_LD_atext
# max =  229
# Prof_occupational_therapist_atext
# max =  7920
# Prof_occupational_therapist_generic_atext
# max =  635
# Prof_oncologist_atext
# max =  2853
# Prof_orthotist_podiatrist_atext
# max =  2032
# Prof_paediatrician_atext
# max =  176
# Prof_physiotherapist_LD_atext
# max =  402
# Prof_physiotherapist_atext
# max =  8072
# Prof_physiotherapist_generic_atext
# max =  649
# Prof_podiatrist_atext
# max =  375
# Prof_psychiatrist_LD_atext
# max =  659
# Prof_psychiatrist_atext
# max =  6244
# Prof_psychiatrist_generic_atext
# max =  668
# Prof_psychologist_LD_atext
# max =  338
# Prof_psychologist_atext
# max =  2909
# Prof_psychologist_generic_atext
# max =  330
# Prof_renal_specialist_atext
# max =  969
# Prof_rheumatologist_atext
# max =  438
# Prof_supported_living_carer_LD_atext
# max =  755
# Prof_surgeon_atext
# max =  1490
# Prof_urologist_atext
# max =  1887
# Professional_IMCA_atext
# max =  3012
# Professional_health_medical_support_atext
# max =  1517
# Professional_health_nursing_support_atext
# max =  2025
# Professional_health_support_LD_services_atext
# max =  1553
# Professional_health_support_allied_atext
# max =  276
# Professional_health_support_primary_atext
# max =  10670
# Professional_health_support_secondary_atext
# max =  22117
# Professional_home_support_atext
# max =  3069
# Professional_private_agencies_atext
# max =  1657
# Professional_support_CLDT_atext
# max =  3704
# Professional_support_advocacy_atext
# max =  1013
# Professional_support_concerns_atext
# max =  204
# Professional_support_concerns_no_atext
# max =  427
# Professional_support_concerns_yes_atext
# max =  6925
# Professional_support_frequency_atext
# max =  1990
# Professional_support_hospice_EOL_atext
# max =  1737
# Professional_support_local_authority_atext
# max =  1296
# Professional_support_voluntary_atext
# max =  357
# Professionals_correct_followup_no_atext
# max =  361
# Professionals_correct_followup_yes_atext
# max =  291
# Professionals_giving_correct_treatment_no_atext
# max =  188
# Professionals_instructions_why_not_atext
# max =  203
# Psychosis_atext
# max =  1309
# Public_protection_plan_atext
# max =  472
# Reasonable_adjustments_atext
# max =  3612
# Reasonable_adjustments_communication_aids_atext
# max =  506
# Reasonable_adjustments_desired_a_quiet_space_atext
# max =  497
# Reasonable_adjustments_desired_atext
# max =  850
# Reasonable_adjustments_desired_communication_aids_atext
# max =  1158
# Reasonable_adjustments_desired_flexibility_on_appts_atext
# max =  323
# Reasonable_adjustments_desired_helpers_in_hospital_atext
# max =  679
# Reasonable_adjustments_desired_home_visit_atext
# max =  520
# Reasonable_adjustments_desired_other_atext
# max =  2613
# Reasonable_adjustments_flexibility_on_appts_atext
# max =  1788
# Reasonable_adjustments_helpers_in_hospital_atext
# max =  663
# Reasonable_adjustments_home_visit_atext
# max =  955
# Reasonable_adjustments_made_a_quiet_space_atext
# max =  936
# Reasonable_adjustments_made_atext
# max =  1473
# Reasonable_adjustments_made_communication_aids_atext
# max =  1182
# Reasonable_adjustments_made_flexibility_on_appts_atext
# max =  844
# Reasonable_adjustments_made_helpers_in_hospital_atext
# max =  1322
# Reasonable_adjustments_made_home_visit_atext
# max =  1281
# Reasonable_adjustments_made_other_atext
# max =  2397
# Reasonable_adjustments_quiet_space_atext
# max =  903
# Regurgitation_reflux_problems_atext
# max =  617
# Residential_home_LD_atext
# max =  1000
# Residential_home_atext
# max =  942
# Residential_home_dementia_atext
# max =  349
# Residential_home_generic_atext
# max =  501
# Residential_home_some_LD_atext
# max =  632
# Restraint_used_atext
# max =  966
# Reviewer_assessment_atext
# max =  5592
# Risk_assessment_latest_date_atext
# max =  1714
# Safeguarding_referral_atext
# max =  1870
# Screening_undertaken_atext
# max =  804
# Sectioned_before_final_year_atext
# max =  1204
# Seizure_type_absence_atext
# max =  38
# Seizure_type_myoclonic_atext
# max =  131
# Seizure_type_tonic_clonic_atext
# max =  178
# Seizures_1_to_4_per_month_atext
# max =  685
# Seizures_day_atext
# max =  180
# Seizures_frequency_atext
# max =  1516
# Seizures_in_last_5_years_atext
# max =  4936
# Seizures_less_than_one_per_month_atext
# max =  364
# Seizures_less_than_one_per_year_atext
# max =  149
# Seizures_over_4_per_month_atext
# max =  2517
# Seizures_recorded_atext
# max =  137
# Seizures_witnessed_atext
# max =  313
# Self_directed_supported_atext
# max =  1409
# Self_harm_atext
# max =  16612
# Sensory_impairment_atext
# max =  481
# Sexual_health_atext
# max =  899
# Significant_friend_atext
# max =  1523
# Skin_conditions_atext
# max =  6602
# Skin_problems_TOD_atext
# max =  787
# Skin_problems_past_atext
# max =  1471
# Sleep_problems_atext
# max =  1383
# Sleep_system_used_atext
# max =  3555
# Slow_eating_atext
# max =  107
# Social_activities_atext
# max =  1232
# Social_atext
# max =  1266
# Social_engagement_atext
# max =  993
# Social_exclusion_atext
# max =  708
# Social_factors_atext
# max =  417
# Speech_problems_yes_atext
# max =  87
# Subject_to_court_order_atext
# max =  206
# Sudden_weight_change_atext
# max =  1524
# Support_freq_24_hours_atext
# max =  780
# Support_freq_at_least_weekly_atext
# max =  706
# Support_freq_daily_atext
# max =  737
# Surgery_last_year_atext
# max =  3716
# Swallow_PEG_PEJ_atext
# max =  3896
# Swallow_assess_before_last_year_atext
# max =  3231
# Swallow_assess_unknown_atext
# max =  299
# Swallow_assess_within_last_year_atext
# max =  2750
# Swallow_breathless_eating_atext
# max =  400
# Swallow_feeding_drink_problem_atext
# max =  445
# Swallow_food_cut_atext
# max =  468
# Swallow_food_mashed_atext
# max =  951
# Swallow_food_pureed_atext
# max =  1601
# Swallow_food_supplements_atext
# max =  4968
# Swallow_history_aspiration_atext
# max =  482
# Swallow_history_choking_atext
# max =  468
# Swallow_nasogastric_atext
# max =  1964
# Swallow_prior_actions_atext
# max =  1726
# Swallow_special_seating_atext
# max =  613
# Swallowing_assessment_atext
# max =  1284
# Swallowing_issues_atext
# max =  252
# Swallowing_issues_dysphagia_atext
# max =  7800
# Targeted_by_others_atext
# max =  3646
# Treatment_escalation_plan_atext
# max =  3936
# Unmet_needs_atext
# max =  3779
# Useful_material_without_code_atext
# max =  5041
# Useful_quote_atext
# max =  3338
# Usually_lives_with_atext
# max =  1099
# Verbal_skills_atext
# max =  550
# Vision_problems_atext
# max =  374
# Vision_problems_no_atext
# max =  341
# Vision_problems_yes_atext
# max =  1390
# Weight_atext
# max =  1534
# case_file_name_atext
# max =  58
# case_file_type_atext
# max =  6
# coder_atext
# max =  9
# report_atext
# max =  46
# N_ID F3.1
# AAA_screening F3.1
# AAA_screening_atext  A69
# AAA_screening_no F3.1
# AAA_screening_no_atext  A197
# AAA_screening_yes F3.1
# AAA_screening_yes_atext  A52
# AP_agencies F3.1
# AP_agencies_atext  A4462
# AP_completed_DNACPR F3.1
# AP_completed_DNACPR_atext  A387
# AP_completed_EOL_care F3.1
# AP_completed_EOL_care_atext  A655
# AP_completed_LD_awareness F3.1
# AP_completed_LD_awareness_atext  A1268
# AP_completed_MCA F3.1
# AP_completed_MCA_atext  A1069
# AP_completed_agencies F3.1
# AP_completed_agencies_atext  A2289
# AP_completed_care_coordination F3.1
# AP_completed_care_coordination_atext  A1123
# AP_completed_documentation F3.1
# AP_completed_documentation_atext  A1071
# AP_completed_family F3.1
# AP_completed_family_atext  A0
# AP_completed_other F3.1
# AP_completed_other_atext  A1693
# AP_completed_reasonable_adjustments F3.1
# AP_completed_reasonable_adjustments_atext  A1221
# AP_completed_role_paid_carers F3.1
# AP_completed_role_paid_carers_atext  A1076
# AP_person F3.1
# AP_person_atext  A1136
# AP_raised_DNACPR F3.1
# AP_raised_DNACPR_atext  A1374
# AP_raised_EOL_care F3.1
# AP_raised_EOL_care_atext  A2379
# AP_raised_LD_awareness F3.1
# AP_raised_LD_awareness_atext  A4064
# AP_raised_MCA F3.1
# AP_raised_MCA_atext  A4327
# AP_raised_agencies F3.1
# AP_raised_agencies_atext  A8946
# AP_raised_care_coordination F3.1
# AP_raised_care_coordination_atext  A3718
# AP_raised_documentation F3.1
# AP_raised_documentation_atext  A2003
# AP_raised_family F3.1
# AP_raised_family_atext  A1821
# AP_raised_other F3.1
# AP_raised_other_atext  A3519
# AP_raised_reasonable_adjustments F3.1
# AP_raised_reasonable_adjustments_atext  A2915
# AP_raised_role_paid_carers F3.1
# AP_raised_role_paid_carers_atext  A1821
# Absences_1_to_4_per_month F3.1
# Absences_1_to_4_per_month_atext  A684
# Absences_frequency F3.1
# Absences_frequency_atext  A642
# Accident_incident F3.1
# Accident_incident_atext  A596
# Accommodation F3.1
# Accommodation_atext  A490
# Accommodation_type F3.1
# Accommodation_type_atext  A274
# Acm_Change_1Yr_Num F3.1
# Acm_Change_1Yr_Num_atext  A2100
# Acm_Change_1Yr_one F3.1
# Acm_Change_1Yr_one_atext  A2100
# Acm_Change_1Yr_over_three F3.1
# Acm_Change_1Yr_over_three_atext  A44
# Acm_Change_1Yr_three F3.1
# Acm_Change_1Yr_three_atext  A774
# Acm_Change_1Yr_two F3.1
# Acm_Change_1Yr_two_atext  A576
# Acm_Iss_1Yr F3.1
# Acm_Iss_1Yr_atext  A2801
# Acm_Iss_Evr F3.1
# Acm_Iss_Evr_atext  A1860
# Acm_Multi_Changes F3.1
# Acm_Multi_Changes_atext  A664
# Acm_TOD_5years_and_more F3.1
# Acm_TOD_5years_and_more_atext  A934
# Acm_TOD_dur_LT_10years F3.1
# Acm_TOD_dur_LT_10years_atext  A207
# Acm_TOD_dur_LT_1month F3.1
# Acm_TOD_dur_LT_1month_atext  A625
# Acm_TOD_dur_LT_1year F3.1
# Acm_TOD_dur_LT_1year_atext  A475
# Acm_TOD_dur_LT_5years F3.1
# Acm_TOD_dur_LT_5years_atext  A858
# Acm_TOD_dur_cat F3.1
# Acm_TOD_dur_cat_atext  A934
# Acm_change_reas_acm F3.1
# Acm_change_reas_acm_atext  A349
# Acm_change_reas_better_accom F3.1
# Acm_change_reas_better_accom_atext  A586
# Acm_change_reas_closure F3.1
# Acm_change_reas_closure_atext  A1245
# Acm_change_reas_pers_condition F3.1
# Acm_change_reas_pers_condition_atext  A2100
# Acm_change_reas_unknown F3.1
# Acm_change_reas_unknown_atext  A447
# Acm_change_reason_cat F3.1
# Acm_change_reason_cat_atext  A2100
# Acm_hist_institution F3.1
# Acm_hist_institution_atext  A756
# Acm_number_occupants F3.1
# Acm_number_occupants_atext  A391
# Action_points_raised F3.1
# Action_points_raised_atext  A902
# Activities F3.1
# Activities_atext  A869
# Adopted F3.1
# Adopted_atext  A564
# Advocate F3.1
# Advocate_atext  A554
# Advocate_no F3.1
# Advocate_no_atext  A851
# Advocate_yes F3.1
# Advocate_yes_atext  A2018
# Agency_safeguarding_referral F3.1
# Agency_safeguarding_referral_atext  A10575
# Alcohol_misuse F3.1
# Alcohol_misuse_atext  A473
# Alcohol_misuse_in_past F3.1
# Alcohol_misuse_in_past_atext  A778
# Alcohol_misuse_yes F3.1
# Alcohol_misuse_yes_atext  A2176
# Allergies F3.1
# Allergies_atext  A775
# Anxiety F3.1
# Anxiety_atext  A1891
# Any_aids_employed F3.1
# Any_aids_employed_atext  A3970
# Appointment_cancelled F3.1
# Appointment_cancelled_atext  A1268
# Aspiration_before_last_year F3.1
# Aspiration_before_last_year_atext  A858
# Aspiration_never F3.1
# Aspiration_never_atext  A72
# Aspiration_unknown F3.1
# Aspiration_unknown_atext  A588
# Aspiration_within_last_year F3.1
# Aspiration_within_last_year_atext  A2624
# Austism_no F3.1
# Austism_no_atext  A19
# Autism_adult_diagnosis F3.1
# Autism_adult_diagnosis_atext  A1048
# Autism_childhood_diagnosis F3.1
# Autism_childhood_diagnosis_atext  A1306
# BMI F3.1
# BMI_atext  A547
# Behaviour_problems F3.1
# Behaviour_problems_atext  A17056
# Best_practice F3.1
# Best_practice_atext  A6137
# Bipolar F3.1
# Bipolar_atext  A2968
# Blood_pressure_high F3.1
# Blood_pressure_high_atext  A1242
# Blood_pressure_low F3.1
# Blood_pressure_low_atext  A1102
# Bowel_cancer_screening F3.1
# Bowel_cancer_screening_atext  A327
# Bowel_cancer_screening_no F3.1
# Bowel_cancer_screening_no_atext  A434
# Bowel_cancer_screening_yes F3.1
# Bowel_cancer_screening_yes_atext  A474
# Breast_cancer_screening F3.1
# Breast_cancer_screening_atext  A1472
# Breast_cancer_screening_no F3.1
# Breast_cancer_screening_no_atext  A445
# Breast_cancer_screening_yes F3.1
# Breast_cancer_screening_yes_atext  A708
# CF_care_coordination F3.1
# CF_care_coordination_atext  A458
# CF_care_provision F3.1
# CF_care_provision_atext  A4037
# CF_care_training_need F3.1
# CF_care_training_need_atext  A458
# CF_family_or_environment F3.1
# CF_family_or_environment_atext  A1990
# CF_healthcare_delay_diagnosis F3.1
# CF_healthcare_delay_diagnosis_atext  A1639
# CF_healthcare_delay_primary F3.1
# CF_healthcare_delay_primary_atext  A121
# CF_healthcare_delay_treatment F3.1
# CF_healthcare_delay_treatment_atext  A241
# CF_pers_mental_health F3.1
# CF_pers_mental_health_atext  A177
# CF_pers_self_harm F3.1
# CF_pers_self_harm_atext  A43
# CF_person F3.1
# CF_person_atext  A2008
# CF_service_provision F3.1
# CF_service_provision_atext  A5567
# Cancer F3.1
# Cancer_atext  A3923
# Cancer_date_referral F3.1
# Cancer_date_referral_atext  A1230
# Cancer_date_symptoms_noticed F3.1
# Cancer_date_symptoms_noticed_atext  A1901
# Cancer_date_symptoms_reported F3.1
# Cancer_date_symptoms_reported_atext  A2112
# Cancer_investigations F3.1
# Cancer_investigations_atext  A1851
# Cancer_investigations_before_referral F3.1
# Cancer_investigations_before_referral_atext  A225
# Cancer_investigations_ordered F3.1
# Cancer_investigations_ordered_atext  A3856
# Cancer_main_symptom F3.1
# Cancer_main_symptom_atext  A3371
# Cancer_spread_metastasis F3.1
# Cancer_spread_metastasis_atext  A2260
# Cancer_stage F3.1
# Cancer_stage_2 F3.1
# Cancer_stage_2_atext  A162
# Cancer_stage_3 F3.1
# Cancer_stage_3_atext  A214
# Cancer_stage_4 F3.1
# Cancer_stage_4_atext  A1013
# Cancer_stage_atext  A477
# Cancer_symptoms_reported_to F3.1
# Cancer_symptoms_reported_to_atext  A127
# Care_plan_EOL F3.1
# Care_plan_EOL_atext  A6813
# Care_plan_dementia F3.1
# Care_plan_dementia_atext  A904
# Care_plan_diabetes F3.1
# Care_plan_diabetes_atext  A1234
# Care_plan_epilepsy F3.1
# Care_plan_epilepsy_atext  A1485
# Care_plan_other F3.1
# Care_plan_other_atext  A5027
# Care_plans F3.1
# Care_plans_atext  A1847
# Cervical_cancer_screening F3.1
# Cervical_cancer_screening_atext  A956
# Cervical_cancer_screening_no F3.1
# Cervical_cancer_screening_no_atext  A464
# Cervical_cancer_screening_yes F3.1
# Cervical_cancer_screening_yes_atext  A242
# Child_in_need F3.1
# Child_in_need_atext  A267
# Choking_before_last_year F3.1
# Choking_before_last_year_atext  A875
# Choking_never F3.1
# Choking_never_atext  A496
# Choking_unknown F3.1
# Choking_unknown_atext  A293
# Choking_within_last_year F3.1
# Choking_within_last_year_atext  A1730
# Circumstances_of_death F3.1
# Circumstances_of_death_atext  A8062
# Clinical_COPD F3.1
# Clinical_COPD_atext  A1531
# Clinical_DVT F3.1
# Clinical_DVT_atext  A1309
# Clinical_UTI F3.1
# Clinical_UTI_atext  A4395
# Clinical_asthma F3.1
# Clinical_asthma_atext  A1735
# Clinical_autism F3.1
# Clinical_autism_atext  A1721
# Clinical_blood_pressure F3.1
# Clinical_blood_pressure_atext  A531
# Clinical_cardiovascular_problem F3.1
# Clinical_cardiovascular_problem_atext  A5049
# Clinical_cerebral_palsy F3.1
# Clinical_cerebral_palsy_atext  A594
# Clinical_condition F3.1
# Clinical_condition_atext  A14149
# Clinical_continence F3.1
# Clinical_continence_atext  A944
# Clinical_degenerative_condition F3.1
# Clinical_degenerative_condition_atext  A1582
# Clinical_dementia F3.1
# Clinical_dementia_atext  A3988
# Clinical_diabetes F3.1
# Clinical_diabetes_atext  A2247
# Clinical_double_incontinence F3.1
# Clinical_double_incontinence_atext  A1307
# Clinical_downs F3.1
# Clinical_downs_atext  A1314
# Clinical_feacal_incontinence F3.1
# Clinical_feacal_incontinence_atext  A1255
# Clinical_genetic_condition F3.1
# Clinical_genetic_condition_atext  A1649
# Clinical_high_cholesterol F3.1
# Clinical_high_cholesterol_atext  A566
# Clinical_history_chest_infections F3.1
# Clinical_history_chest_infections_atext  A3175
# Clinical_history_falls F3.1
# Clinical_history_falls_atext  A2963
# Clinical_kidney_problems F3.1
# Clinical_kidney_problems_atext  A5035
# Clinical_osteoporisis F3.1
# Clinical_osteoporisis_atext  A898
# Clinical_pneumonia_aspiration F3.1
# Clinical_pneumonia_aspiration_atext  A2632
# Clinical_pneumonia_infectious F3.1
# Clinical_pneumonia_infectious_atext  A1599
# Clinical_prostate_problems F3.1
# Clinical_prostate_problems_atext  A1076
# Clinical_sepsis F3.1
# Clinical_sepsis_atext  A1020
# Clinical_urinary_incontinent F3.1
# Clinical_urinary_incontinent_atext  A833
# Communication_abilities F3.1
# Communication_abilities_atext  A1493
# Constipation F3.1
# Constipation_atext  A3129
# Continence_aids F3.1
# Continence_aids_atext  A1417
# Contraception F3.1
# Contraception_atext  A1011
# Contributory_factor_COD F3.1
# Contributory_factor_COD_atext  A371
# DNACPR F3.1
# DNACPR_atext  A713
# DNACPR_comments F3.1
# DNACPR_comments_atext  A8263
# Daytime_activities F3.1
# Daytime_activities_atext  A204
# Daytime_independent_activities F3.1
# Daytime_independent_activities_atext  A702
# Death_from_fall F3.1
# Death_from_fall_atext  A63
# Death_from_other_accidents F3.1
# Death_from_other_accidents_atext  A1803
# Death_from_road_accident F3.1
# Death_from_road_accident_atext  A1019
# Death_from_suicide F3.1
# Death_from_suicide_atext  A4752
# Dental_issues F3.1
# Dental_issues_atext  A2167
# Dental_last_check F3.1
# Dental_last_check_atext  A140
# Dental_last_check_date F3.1
# Dental_last_check_date_atext  A141
# Dental_regular_care F3.1
# Dental_regular_care_atext  A602
# Depression F3.1
# Depression_atext  A1858
# Diabetes_type_1 F3.1
# Diabetes_type_1_atext  A5242
# Diabetes_type_2 F3.1
# Diabetes_type_2_atext  A4490
# Diabetes_type_unspecified F3.1
# Diabetes_type_unspecified_atext  A3437
# Difficulties_services_with_carer F3.1
# Difficulties_services_with_carer_atext  A1806
# Domestic_violence_household F3.1
# Domestic_violence_household_atext  A701
# Drug_misuse F3.1
# Drug_misuse_atext  A331
# Drug_misuse_in_past F3.1
# Drug_misuse_in_past_atext  A345
# Drug_misuse_yes F3.1
# Drug_misuse_yes_atext  A798
# Eating_disorder F3.1
# Eating_disorder_atext  A613
# Employment F3.1
# Employment_at_TOD F3.1
# Employment_at_TOD_atext  A116
# Employment_atext  A553
# Employment_ever_no F3.1
# Employment_ever_no_atext  A291
# Employment_ever_yes F3.1
# Employment_ever_yes_atext  A468
# Employment_paid_ever F3.1
# Employment_paid_ever_atext  A244
# Epi_care_plan F3.1
# Epi_care_plan_atext  A139
# Epi_frequecy_duration F3.1
# Epi_frequecy_duration_atext  A654
# Epi_manage_descr F3.1
# Epi_manage_descr_atext  A5978
# Epilepsy F3.1
# Epilepsy_atext  A3988
# Event_of_death_issues F3.1
# Event_of_death_issues_atext  A179
# Fam_carers_supported F3.1
# Fam_carers_supported_atext  A482
# Fam_carers_supported_no F3.1
# Fam_carers_supported_no_atext  A968
# Fam_carers_supported_yes F3.1
# Fam_carers_supported_yes_atext  A2871
# Fam_contact_child F3.1
# Fam_contact_child_atext  A456
# Fam_contact_dail1y F3.1
# Fam_contact_dail1y_atext  A144
# Fam_contact_few_times_yearly F3.1
# Fam_contact_few_times_yearly_atext  A221
# Fam_contact_frequently F3.1
# Fam_contact_frequently_atext  A1230
# Fam_contact_infrequently F3.1
# Fam_contact_infrequently_atext  A1048
# Fam_contact_less_than_yearly F3.1
# Fam_contact_less_than_yearly_atext  A282
# Fam_contact_monthly F3.1
# Fam_contact_monthly_atext  A468
# Fam_contact_never F3.1
# Fam_contact_never_atext  A1021
# Fam_contact_other F3.1
# Fam_contact_other_atext  A954
# Fam_contact_parent F3.1
# Fam_contact_parent_atext  A395
# Fam_contact_sibling F3.1
# Fam_contact_sibling_atext  A413
# Fam_contact_unspecified F3.1
# Fam_contact_unspecified_atext  A179
# Fam_contact_weekly F3.1
# Fam_contact_weekly_atext  A227
# Fam_listened_to_no F3.1
# Fam_listened_to_no_atext  A2712
# Fam_listened_to_yes F3.1
# Fam_listened_to_yes_atext  A1370
# Fam_rel_concerns F3.1
# Fam_rel_concerns_atext  A1294
# Fam_rel_poor F3.1
# Fam_rel_poor_atext  A3718
# Fam_rel_seemed_good F3.1
# Fam_rel_seemed_good_atext  A1626
# Fam_rel_unknown F3.1
# Fam_rel_unknown_atext  A344
# Families_listened_to F3.1
# Families_listened_to_atext  A503
# Family_carers F3.1
# Family_carers_atext  A1478
# Family_carers_no F3.1
# Family_carers_no_atext  A651
# Family_carers_views_of_death F3.1
# Family_carers_views_of_death_atext  A6764
# Family_carers_yes F3.1
# Family_carers_yes_atext  A1478
# Family_concerns_about_death F3.1
# Family_concerns_about_death_atext  A2550
# Family_contact_regularity F3.1
# Family_contact_regularity_atext  A539
# Family_contacts_members F3.1
# Family_contacts_members_atext  A197
# Family_relationships F3.1
# Family_relationships_atext  A777
# Family_relative_deceased F3.1
# Family_relative_deceased_atext  A1054
# Family_safeguarding_referral F3.1
# Family_safeguarding_referral_atext  A2953
# Fear_of_doctor_or_treatment F3.1
# Fear_of_doctor_or_treatment_atext  A1767
# Fear_of_doctor_sensitization F3.1
# Fear_of_doctor_sensitization_atext  A1044
# Fiinancial_abuse F3.1
# Fiinancial_abuse_atext  A1860
# Financial_abuse F3.1
# Financial_abuse_atext  A4974
# Financial_circumstances F3.1
# Financial_circumstances_atext  A4845
# Good_practice F3.1
# Good_practice_EOL F3.1
# Good_practice_EOL_atext  A3470
# Good_practice_MCA F3.1
# Good_practice_MCA_atext  A3444
# Good_practice_atext  A2694
# Good_practice_care_coordination F3.1
# Good_practice_care_coordination_atext  A3167
# Good_practice_care_provider F3.1
# Good_practice_care_provider_atext  A3587
# Good_practice_primary F3.1
# Good_practice_primary_atext  A3642
# Good_practice_review F3.1
# Good_practice_review_atext  A5395
# Good_practice_secondary F3.1
# Good_practice_secondary_atext  A3087
# Good_practice_transition F3.1
# Good_practice_transition_atext  A882
# Good_verbal_communication F3.1
# Good_verbal_communication_atext  A1758
# Health F3.1
# Health_action_plan F3.1
# Health_action_plan_atext  A1108
# Health_action_plan_no F3.1
# Health_action_plan_no_atext  A473
# Health_action_plan_yes F3.1
# Health_action_plan_yes_atext  A4929
# Health_atext  A2052
# Health_checks F3.1
# Health_checks_annual_LD F3.1
# Health_checks_annual_LD_atext  A503
# Health_checks_anual_LD F3.1
# Health_checks_anual_LD_atext  A1011
# Health_checks_atext  A829
# Healthcare_institutions_processes F3.1
# Healthcare_institutions_processes_atext  A1406
# Hearing_problems F3.1
# Hearing_problems_atext  A167
# Hearing_problems_no F3.1
# Hearing_problems_no_atext  A425
# Hearing_problems_yes F3.1
# Hearing_problems_yes_atext  A915
# Height F3.1
# Height_atext  A40
# Height_weight_BMI F3.1
# Height_weight_BMI_atext  A547
# Holidays F3.1
# Holidays_atext  A1356
# Hospice F3.1
# Hospice_atext  A1251
# Hospital_communication_document F3.1
# Hospital_communication_document_atext  A800
# Hospital_communication_document_no F3.1
# Hospital_communication_document_no_atext  A542
# Hospital_communication_document_yes F3.1
# Hospital_communication_document_yes_atext  A927
# Housing_provider F3.1
# Housing_provider_atext  A1226
# Immunised_against_flu F3.1
# Immunised_against_flu_atext  A250
# Immunised_against_flu_no F3.1
# Immunised_against_flu_no_atext  A728
# Immunised_against_flu_yes F3.1
# Immunised_against_flu_yes_atext  A731
# Independently_mobile F3.1
# Independently_mobile_atext  A662
# Informal_supp_family_other_house F3.1
# Informal_supp_family_other_house_atext  A744
# Informal_supp_friends_other_house F3.1
# Informal_supp_friends_other_house_atext  A1881
# Informal_supp_friends_same_house F3.1
# Informal_supp_friends_same_house_atext  A703
# Informal_support F3.1
# Informal_support_atext  A387
# Institution_long_stay_hospital F3.1
# Institution_long_stay_hospital_atext  A334
# Interpersonal_relationships F3.1
# Interpersonal_relationships_atext  A1350
# Issues F3.1
# Issues_agencies F3.1
# Issues_agencies_atext  A19598
# Issues_atext  A4960
# Issues_family F3.1
# Issues_family_atext  A18399
# Issues_person F3.1
# Issues_person_atext  A8095
# Known_to_police F3.1
# Known_to_police_atext  A1135
# Known_to_police_in_past F3.1
# Known_to_police_in_past_atext  A1860
# Known_to_police_yes F3.1
# Known_to_police_yes_atext  A4599
# LA_childrens_social_services F3.1
# LA_childrens_social_services_atext  A288
# LA_education F3.1
# LA_education_atext  A856
# LA_support_day_services_LD F3.1
# LA_support_day_services_LD_atext  A466
# LA_support_day_services_generic F3.1
# LA_support_day_services_generic_atext  A1933
# LA_support_respite F3.1
# LA_support_respite_atext  A2578
# LA_support_social_worker_CLDT F3.1
# LA_support_social_worker_CLDT_atext  A2089
# LA_support_social_worker_generic F3.1
# LA_support_social_worker_generic_atext  A8901
# LA_support_worker F3.1
# LA_support_worker_atext  A6404
# LD_severity F3.1
# LD_severity_atext  A893
# LD_severity_mild F3.1
# LD_severity_mild_atext  A382
# LD_severity_moderate F3.1
# LD_severity_moderate_atext  A342
# LD_severity_profound_multiple F3.1
# LD_severity_profound_multiple_atext  A301
# LD_severity_severe F3.1
# LD_severity_severe_atext  A504
# Last_dental_check_inside_1_year F3.1
# Last_dental_check_inside_1_year_atext  A456
# Last_dental_check_over_1_year F3.1
# Last_dental_check_over_1_year_atext  A164
# Last_health_check_date F3.1
# Last_health_check_date_atext  A654
# Last_health_check_never F3.1
# Last_health_check_never_atext  A50
# Last_health_check_over_1_year F3.1
# Last_health_check_over_1_year_atext  A738
# Last_health_check_within_1_month F3.1
# Last_health_check_within_1_month_atext  A217
# Last_health_check_within_1_year F3.1
# Last_health_check_within_1_year_atext  A6829
# Last_health_check_within_3_months F3.1
# Last_health_check_within_3_months_atext  A423
# Last_health_check_within_6_months F3.1
# Last_health_check_within_6_months_atext  A120
# Last_meds_review F3.1
# Last_meds_review_6_months F3.1
# Last_meds_review_6_months_atext  A897
# Last_meds_review_atext  A734
# Last_meds_review_month F3.1
# Last_meds_review_month_atext  A716
# Last_meds_review_over_year F3.1
# Last_meds_review_over_year_atext  A654
# Last_meds_review_quarter F3.1
# Last_meds_review_quarter_atext  A657
# Last_meds_review_week F3.1
# Last_meds_review_week_atext  A665
# Last_meds_review_year F3.1
# Last_meds_review_year_atext  A386
# Last_risk_assessment_over_1_year F3.1
# Last_risk_assessment_over_1_year_atext  A428
# Last_risk_assessment_within_1_month F3.1
# Last_risk_assessment_within_1_month_atext  A737
# Last_risk_assessment_within_1_year F3.1
# Last_risk_assessment_within_1_year_atext  A649
# Last_risk_assessment_within_3_months F3.1
# Last_risk_assessment_within_3_months_atext  A1160
# Last_risk_assessment_within_6_months F3.1
# Last_risk_assessment_within_6_months_atext  A1005
# Legal_involvement F3.1
# Legal_involvement_atext  A3198
# Limited_verbal_communication F3.1
# Limited_verbal_communication_atext  A1026
# Literacy_skills F3.1
# Literacy_skills_atext  A241
# Literate F3.1
# Literate_atext  A554
# Living_alone F3.1
# Living_alone_atext  A652
# Living_alone_spouse_partner F3.1
# Living_alone_spouse_partner_atext  A1099
# Living_with_carer F3.1
# Living_with_carer_atext  A481
# Living_with_friends F3.1
# Living_with_friends_atext  A328
# Living_with_other_family F3.1
# Living_with_other_family_atext  A725
# Living_with_other_residents F3.1
# Living_with_other_residents_atext  A855
# Living_with_parent F3.1
# Living_with_parent_atext  A694
# MCA_comment F3.1
# MCA_comment_atext  A132
# MCA_comments F3.1
# MCA_comments_atext  A12644
# Medical_histories F3.1
# Medical_histories_atext  A32760
# Medical_intervention_details F3.1
# Medical_intervention_details_atext  A17258
# Medical_interventions F3.1
# Medical_interventions_atext  A8138
# Medications F3.1
# Medications_atext  A12040
# Meds_antidepressants F3.1
# Meds_antidepressants_atext  A1001
# Meds_antiepileptics F3.1
# Meds_antiepileptics_atext  A1642
# Meds_antipsychotics F3.1
# Meds_antipsychotics_atext  A1588
# Meds_anxiolytics F3.1
# Meds_anxiolytics_atext  A961
# Meds_hypnotics F3.1
# Meds_hypnotics_atext  A293
# Meds_non_opioid_analgesics F3.1
# Meds_non_opioid_analgesics_atext  A213
# Meds_opioid_analgesics F3.1
# Meds_opioid_analgesics_atext  A222
# Mental_health_other F3.1
# Mental_health_other_atext  A1479
# Mental_psychological_conditions F3.1
# Mental_psychological_conditions_atext  A2048
# Mobility F3.1
# Mobility_atext  A1768
# Mobility_some_support F3.1
# Mobility_some_support_atext  A1443
# Mobility_total_support F3.1
# Mobility_total_support_atext  A1488
# Most_recent_review_support F3.1
# Most_recent_review_support_atext  A2136
# Motor_impairement F3.1
# Motor_impairement_atext  A1614
# Motor_impairement_hand F3.1
# Motor_impairement_hand_atext  A1171
# Motor_impairment F3.1
# Motor_impairment_atext  A395
# Motore_impairment_hand F3.1
# Motore_impairment_hand_atext  A658
# No_apparent_illness F3.1
# No_apparent_illness_atext  A3665
# No_teeth F3.1
# No_teeth_atext  A82
# No_verbal_communication F3.1
# No_verbal_communication_atext  A1072
# Not_literate F3.1
# Not_literate_atext  A259
# Number_private_occupants_3_to_5 F3.1
# Number_private_occupants_3_to_5_atext  A58
# Nursing_CLDT_nurse F3.1
# Nursing_CLDT_nurse_atext  A29668
# Nursing_GP_practice_nurse F3.1
# Nursing_GP_practice_nurse_atext  A3573
# Nursing_LD_liaison_nurse F3.1
# Nursing_LD_liaison_nurse_atext  A4009
# Nursing_LD_specialist F3.1
# Nursing_LD_specialist_atext  A3066
# Nursing_PEG_nurse F3.1
# Nursing_PEG_nurse_atext  A305
# Nursing_cardiac_nurse F3.1
# Nursing_cardiac_nurse_atext  A282
# Nursing_community_matron F3.1
# Nursing_community_matron_atext  A1127
# Nursing_community_nurse F3.1
# Nursing_community_nurse_atext  A2152
# Nursing_community_palliative_nurse F3.1
# Nursing_community_palliative_nurse_atext  A1686
# Nursing_community_psychiatric_nurse F3.1
# Nursing_community_psychiatric_nurse_atext  A1200
# Nursing_community_services F3.1
# Nursing_community_services_atext  A995
# Nursing_continence_nurse F3.1
# Nursing_continence_nurse_atext  A403
# Nursing_dementia_nurse F3.1
# Nursing_dementia_nurse_atext  A1536
# Nursing_diabetes_nurse F3.1
# Nursing_diabetes_nurse_atext  A3228
# Nursing_district_nurse F3.1
# Nursing_district_nurse_atext  A9107
# Nursing_epilepsy_nurse F3.1
# Nursing_epilepsy_nurse_atext  A2095
# Nursing_for_end_of_life F3.1
# Nursing_for_end_of_life_atext  A1987
# Nursing_home F3.1
# Nursing_home_LD F3.1
# Nursing_home_LD_atext  A262
# Nursing_home_atext  A1041
# Nursing_home_dementia F3.1
# Nursing_home_dementia_atext  A495
# Nursing_home_generic F3.1
# Nursing_home_generic_atext  A816
# Nursing_home_some_LD F3.1
# Nursing_home_some_LD_atext  A624
# Nursing_hospice F3.1
# Nursing_hospice_atext  A1514
# Nursing_hospital_liaison_nurse F3.1
# Nursing_hospital_liaison_nurse_atext  A3717
# Nursing_hospital_palliative_nurse F3.1
# Nursing_hospital_palliative_nurse_atext  A2294
# Nursing_non_LD_specialist F3.1
# Nursing_non_LD_specialist_atext  A833
# Nursing_primary_care F3.1
# Nursing_primary_care_atext  A1400
# Nursing_respiratory_nurse F3.1
# Nursing_respiratory_nurse_atext  A415
# Nursing_stroke_nurse F3.1
# Nursing_stroke_nurse_atext  A199
# Nursing_tissue_viability_nurse F3.1
# Nursing_tissue_viability_nurse_atext  A9893
# On_LD_register F3.1
# On_LD_register_atext  A452
# On_LD_register_no F3.1
# On_LD_register_no_atext  A746
# On_LD_register_yes F3.1
# On_LD_register_yes_atext  A457
# Other_private_residence F3.1
# Other_private_residence_atext  A609
# Other_safeguarding_referral F3.1
# Other_safeguarding_referral_atext  A5053
# Other_sensory_impairment F3.1
# Other_sensory_impairment_atext  A332
# Own_home F3.1
# Own_home_atext  A664
# PT_paid F3.1
# PT_paid_atext  A149
# PT_voluntary F3.1
# PT_voluntary_atext  A245
# Paid_carer_agency F3.1
# Paid_carer_agency_atext  A15
# Pain_assessment F3.1
# Pain_assessment_atext  A1530
# Pain_assessment_no F3.1
# Pain_assessment_no_atext  A435
# Pain_assessment_yes F3.1
# Pain_assessment_yes_atext  A1032
# Pain_issues F3.1
# Pain_issues_atext  A1728
# Pain_long_term F3.1
# Pain_long_term_atext  A2408
# Pain_unresolved F3.1
# Pain_unresolved_atext  A491
# Parental_home F3.1
# Parental_home_atext  A708
# Parents F3.1
# Parents_atext  A224
# Patient_engagement F3.1
# Patient_engagement_atext  A3068
# Patient_involved_in_decisions F3.1
# Patient_involved_in_decisions_atext  A2589
# Patient_missed_appointment F3.1
# Patient_missed_appointment_atext  A3252
# Patients_family_brought_in F3.1
# Patients_family_brought_in_atext  A3523
# Person_refused_treatment F3.1
# Person_refused_treatment_atext  A3120
# Personal_healthcare F3.1
# Personal_healthcare_atext  A996
# Personal_healthcare_full_support F3.1
# Personal_healthcare_full_support_atext  A1512
# Personal_healthcare_independent F3.1
# Personal_healthcare_independent_atext  A673
# Personal_healthcare_some_support F3.1
# Personal_healthcare_some_support_atext  A2287
# Persons_family_brought_in F3.1
# Persons_family_brought_in_atext  A1365
# Poor_practice F3.1
# Poor_practice_EOL F3.1
# Poor_practice_EOL_atext  A2761
# Poor_practice_MCA F3.1
# Poor_practice_MCA_atext  A3609
# Poor_practice_atext  A2709
# Poor_practice_care_coordination F3.1
# Poor_practice_care_coordination_atext  A8285
# Poor_practice_care_provider F3.1
# Poor_practice_care_provider_atext  A11472
# Poor_practice_primary F3.1
# Poor_practice_primary_atext  A3342
# Poor_practice_review F3.1
# Poor_practice_review_atext  A837
# Poor_practice_secondary F3.1
# Poor_practice_secondary_atext  A6156
# Poor_practice_transition F3.1
# Poor_practice_transition_atext  A1856
# Posture_needs F3.1
# Posture_needs_atext  A3794
# Pressure_sores F3.1
# Pressure_sores_atext  A6410
# Previous_hospital_admissions F3.1
# Previous_hospital_admissions_atext  A7250
# Previous_pregnancy F3.1
# Previous_pregnancy_atext  A562
# Prof_CAMHS F3.1
# Prof_CAMHS_atext  A0
# Prof_CLDT F3.1
# Prof_CLDT_atext  A9284
# Prof_GP_no F3.1
# Prof_GP_no_atext  A168
# Prof_LD_nurse F3.1
# Prof_LD_nurse_atext  A957
# Prof_SALT F3.1
# Prof_SALT_LD F3.1
# Prof_SALT_LD_atext  A926
# Prof_SALT_atext  A10843
# Prof_SALT_generic F3.1
# Prof_SALT_generic_atext  A1220
# Prof_art_music_drama_therapist F3.1
# Prof_art_music_drama_therapist_atext  A321
# Prof_cardiologist F3.1
# Prof_cardiologist_atext  A2361
# Prof_care_home_carer_LD F3.1
# Prof_care_home_carer_LD_atext  A1023
# Prof_care_home_carer_generic F3.1
# Prof_care_home_carer_generic_atext  A710
# Prof_dietician F3.1
# Prof_dietician_atext  A1438
# Prof_direct_payment_brokers F3.1
# Prof_direct_payment_brokers_atext  A596
# Prof_gastroenterologist F3.1
# Prof_gastroenterologist_atext  A2842
# Prof_gynaecologist F3.1
# Prof_gynaecologist_atext  A1187
# Prof_neurologist F3.1
# Prof_neurologist_atext  A3606
# Prof_nursing_home_carer_LD F3.1
# Prof_nursing_home_carer_LD_atext  A288
# Prof_nursing_home_carer_generic F3.1
# Prof_nursing_home_carer_generic_atext  A497
# Prof_occupational_therapist F3.1
# Prof_occupational_therapist_LD F3.1
# Prof_occupational_therapist_LD_atext  A229
# Prof_occupational_therapist_atext  A7920
# Prof_occupational_therapist_generic F3.1
# Prof_occupational_therapist_generic_atext  A635
# Prof_oncologist F3.1
# Prof_oncologist_atext  A2853
# Prof_orthotist_podiatrist F3.1
# Prof_orthotist_podiatrist_atext  A2032
# Prof_paediatrician F3.1
# Prof_paediatrician_atext  A176
# Prof_physiotherapist F3.1
# Prof_physiotherapist_LD F3.1
# Prof_physiotherapist_LD_atext  A402
# Prof_physiotherapist_atext  A8072
# Prof_physiotherapist_generic F3.1
# Prof_physiotherapist_generic_atext  A649
# Prof_podiatrist F3.1
# Prof_podiatrist_atext  A375
# Prof_psychiatrist F3.1
# Prof_psychiatrist_LD F3.1
# Prof_psychiatrist_LD_atext  A659
# Prof_psychiatrist_atext  A6244
# Prof_psychiatrist_generic F3.1
# Prof_psychiatrist_generic_atext  A668
# Prof_psychologist F3.1
# Prof_psychologist_LD F3.1
# Prof_psychologist_LD_atext  A338
# Prof_psychologist_atext  A2909
# Prof_psychologist_generic F3.1
# Prof_psychologist_generic_atext  A330
# Prof_renal_specialist F3.1
# Prof_renal_specialist_atext  A969
# Prof_rheumatologist F3.1
# Prof_rheumatologist_atext  A438
# Prof_supported_living_carer_LD F3.1
# Prof_supported_living_carer_LD_atext  A755
# Prof_surgeon F3.1
# Prof_surgeon_atext  A1490
# Prof_urologist F3.1
# Prof_urologist_atext  A1887
# Professional_IMCA F3.1
# Professional_IMCA_atext  A3012
# Professional_health_medical_support F3.1
# Professional_health_medical_support_atext  A1517
# Professional_health_nursing_support F3.1
# Professional_health_nursing_support_atext  A2025
# Professional_health_support_LD_services F3.1
# Professional_health_support_LD_services_atext  A1553
# Professional_health_support_allied F3.1
# Professional_health_support_allied_atext  A276
# Professional_health_support_primary F3.1
# Professional_health_support_primary_atext  A10670
# Professional_health_support_secondary F3.1
# Professional_health_support_secondary_atext  A22117
# Professional_home_support F3.1
# Professional_home_support_atext  A3069
# Professional_private_agencies F3.1
# Professional_private_agencies_atext  A1657
# Professional_support_CLDT F3.1
# Professional_support_CLDT_atext  A3704
# Professional_support_advocacy F3.1
# Professional_support_advocacy_atext  A1013
# Professional_support_concerns F3.1
# Professional_support_concerns_atext  A204
# Professional_support_concerns_no F3.1
# Professional_support_concerns_no_atext  A427
# Professional_support_concerns_yes F3.1
# Professional_support_concerns_yes_atext  A6925
# Professional_support_frequency F3.1
# Professional_support_frequency_atext  A1990
# Professional_support_hospice_EOL F3.1
# Professional_support_hospice_EOL_atext  A1737
# Professional_support_local_authority F3.1
# Professional_support_local_authority_atext  A1296
# Professional_support_voluntary F3.1
# Professional_support_voluntary_atext  A357
# Professionals_correct_followup_no F3.1
# Professionals_correct_followup_no_atext  A361
# Professionals_correct_followup_yes F3.1
# Professionals_correct_followup_yes_atext  A291
# Professionals_giving_correct_treatment_no F3.1
# Professionals_giving_correct_treatment_no_atext  A188
# Professionals_instructions_why_not F3.1
# Professionals_instructions_why_not_atext  A203
# Psychosis F3.1
# Psychosis_atext  A1309
# Public_protection_plan F3.1
# Public_protection_plan_atext  A472
# Reasonable_adjustments F3.1
# Reasonable_adjustments_atext  A3612
# Reasonable_adjustments_communication_aids F3.1
# Reasonable_adjustments_communication_aids_atext  A506
# Reasonable_adjustments_desired F3.1
# Reasonable_adjustments_desired_a_quiet_space F3.1
# Reasonable_adjustments_desired_a_quiet_space_atext  A497
# Reasonable_adjustments_desired_atext  A850
# Reasonable_adjustments_desired_communication_aids F3.1
# Reasonable_adjustments_desired_communication_aids_atext  A1158
# Reasonable_adjustments_desired_flexibility_on_appts F3.1
# Reasonable_adjustments_desired_flexibility_on_appts_atext  A323
# Reasonable_adjustments_desired_helpers_in_hospital F3.1
# Reasonable_adjustments_desired_helpers_in_hospital_atext  A679
# Reasonable_adjustments_desired_home_visit F3.1
# Reasonable_adjustments_desired_home_visit_atext  A520
# Reasonable_adjustments_desired_other F3.1
# Reasonable_adjustments_desired_other_atext  A2613
# Reasonable_adjustments_flexibility_on_appts F3.1
# Reasonable_adjustments_flexibility_on_appts_atext  A1788
# Reasonable_adjustments_helpers_in_hospital F3.1
# Reasonable_adjustments_helpers_in_hospital_atext  A663
# Reasonable_adjustments_home_visit F3.1
# Reasonable_adjustments_home_visit_atext  A955
# Reasonable_adjustments_made F3.1
# Reasonable_adjustments_made_a_quiet_space F3.1
# Reasonable_adjustments_made_a_quiet_space_atext  A936
# Reasonable_adjustments_made_atext  A1473
# Reasonable_adjustments_made_communication_aids F3.1
# Reasonable_adjustments_made_communication_aids_atext  A1182
# Reasonable_adjustments_made_flexibility_on_appts F3.1
# Reasonable_adjustments_made_flexibility_on_appts_atext  A844
# Reasonable_adjustments_made_helpers_in_hospital F3.1
# Reasonable_adjustments_made_helpers_in_hospital_atext  A1322
# Reasonable_adjustments_made_home_visit F3.1
# Reasonable_adjustments_made_home_visit_atext  A1281
# Reasonable_adjustments_made_other F3.1
# Reasonable_adjustments_made_other_atext  A2397
# Reasonable_adjustments_quiet_space F3.1
# Reasonable_adjustments_quiet_space_atext  A903
# Regurgitation_reflux_problems F3.1
# Regurgitation_reflux_problems_atext  A617
# Residential_home F3.1
# Residential_home_LD F3.1
# Residential_home_LD_atext  A1000
# Residential_home_atext  A942
# Residential_home_dementia F3.1
# Residential_home_dementia_atext  A349
# Residential_home_generic F3.1
# Residential_home_generic_atext  A501
# Residential_home_some_LD F3.1
# Residential_home_some_LD_atext  A632
# Restraint_used F3.1
# Restraint_used_atext  A966
# Reviewer_assessment F3.1
# Reviewer_assessment_atext  A5592
# Risk_assessment_latest_date F3.1
# Risk_assessment_latest_date_atext  A1714
# Safeguarding_referral F3.1
# Safeguarding_referral_atext  A1870
# Screening_undertaken F3.1
# Screening_undertaken_atext  A804
# Sectioned_before_final_year F3.1
# Sectioned_before_final_year_atext  A1204
# Seizure_type_absence F3.1
# Seizure_type_absence_atext  A38
# Seizure_type_myoclonic F3.1
# Seizure_type_myoclonic_atext  A131
# Seizure_type_tonic_clonic F3.1
# Seizure_type_tonic_clonic_atext  A178
# Seizures_1_to_4_per_month F3.1
# Seizures_1_to_4_per_month_atext  A685
# Seizures_day F3.1
# Seizures_day_atext  A180
# Seizures_frequency F3.1
# Seizures_frequency_atext  A1516
# Seizures_in_last_5_years F3.1
# Seizures_in_last_5_years_atext  A4936
# Seizures_less_than_one_per_month F3.1
# Seizures_less_than_one_per_month_atext  A364
# Seizures_less_than_one_per_year F3.1
# Seizures_less_than_one_per_year_atext  A149
# Seizures_over_4_per_month F3.1
# Seizures_over_4_per_month_atext  A2517
# Seizures_recorded F3.1
# Seizures_recorded_atext  A137
# Seizures_witnessed F3.1
# Seizures_witnessed_atext  A313
# Self_directed_supported F3.1
# Self_directed_supported_atext  A1409
# Self_harm F3.1
# Self_harm_atext  A16612
# Sensory_impairment F3.1
# Sensory_impairment_atext  A481
# Sexual_health F3.1
# Sexual_health_atext  A899
# Significant_friend F3.1
# Significant_friend_atext  A1523
# Skin_conditions F3.1
# Skin_conditions_atext  A6602
# Skin_problems_TOD F3.1
# Skin_problems_TOD_atext  A787
# Skin_problems_past F3.1
# Skin_problems_past_atext  A1471
# Sleep_problems F3.1
# Sleep_problems_atext  A1383
# Sleep_system_used F3.1
# Sleep_system_used_atext  A3555
# Slow_eating F3.1
# Slow_eating_atext  A107
# Social F3.1
# Social_activities F3.1
# Social_activities_atext  A1232
# Social_atext  A1266
# Social_engagement F3.1
# Social_engagement_atext  A993
# Social_exclusion F3.1
# Social_exclusion_atext  A708
# Social_factors F3.1
# Social_factors_atext  A417
# Speech_problems_yes F3.1
# Speech_problems_yes_atext  A87
# Subject_to_court_order F3.1
# Subject_to_court_order_atext  A206
# Sudden_weight_change F3.1
# Sudden_weight_change_atext  A1524
# Support_freq_24_hours F3.1
# Support_freq_24_hours_atext  A780
# Support_freq_at_least_weekly F3.1
# Support_freq_at_least_weekly_atext  A706
# Support_freq_daily F3.1
# Support_freq_daily_atext  A737
# Surgery_last_year F3.1
# Surgery_last_year_atext  A3716
# Swallow_PEG_PEJ F3.1
# Swallow_PEG_PEJ_atext  A3896
# Swallow_assess_before_last_year F3.1
# Swallow_assess_before_last_year_atext  A3231
# Swallow_assess_unknown F3.1
# Swallow_assess_unknown_atext  A299
# Swallow_assess_within_last_year F3.1
# Swallow_assess_within_last_year_atext  A2750
# Swallow_breathless_eating F3.1
# Swallow_breathless_eating_atext  A400
# Swallow_feeding_drink_problem F3.1
# Swallow_feeding_drink_problem_atext  A445
# Swallow_food_cut F3.1
# Swallow_food_cut_atext  A468
# Swallow_food_mashed F3.1
# Swallow_food_mashed_atext  A951
# Swallow_food_pureed F3.1
# Swallow_food_pureed_atext  A1601
# Swallow_food_supplements F3.1
# Swallow_food_supplements_atext  A4968
# Swallow_history_aspiration F3.1
# Swallow_history_aspiration_atext  A482
# Swallow_history_choking F3.1
# Swallow_history_choking_atext  A468
# Swallow_nasogastric F3.1
# Swallow_nasogastric_atext  A1964
# Swallow_prior_actions F3.1
# Swallow_prior_actions_atext  A1726
# Swallow_special_seating F3.1
# Swallow_special_seating_atext  A613
# Swallowing_assessment F3.1
# Swallowing_assessment_atext  A1284
# Swallowing_issues F3.1
# Swallowing_issues_atext  A252
# Swallowing_issues_dysphagia F3.1
# Swallowing_issues_dysphagia_atext  A7800
# Targeted_by_others F3.1
# Targeted_by_others_atext  A3646
# Treatment_escalation_plan F3.1
# Treatment_escalation_plan_atext  A3936
# Unmet_needs F3.1
# Unmet_needs_atext  A3779
# Useful_material_without_code F3.1
# Useful_material_without_code_atext  A5041
# Useful_quote F3.1
# Useful_quote_atext  A3338
# Usually_lives_with F3.1
# Usually_lives_with_atext  A1099
# Verbal_skills F3.1
# Verbal_skills_atext  A550
# Vision_problems F3.1
# Vision_problems_atext  A374
# Vision_problems_no F3.1
# Vision_problems_no_atext  A341
# Vision_problems_yes F3.1
# Vision_problems_yes_atext  A1390
# Weight F3.1
# Weight_atext  A1534
# case_file_name_atext  A58
# case_file_type_atext  A6
# coder_atext  A9
# report_atext  A46
# number_codes F3.1

# %%
# writing SPSS syntax file to load data.
# note that there must be no whitespaces after the final backslash for each line, as this will cause an error to be thrown

file=open('nvivo_normal_spss_sytax.sps','w')
file.write('* Encoding: UTF-8.\n')
file.write('PRESERVE. \nSET DECIMAL DOT.\n')
file.write('GET DATA  /TYPE=TXT \n \
  /FILE="\\\\ads\\filestore\\Deaf_Studies\\Deaf\\nfrc\LeDeR confidential\\Data Entry\\Avon\\reviews_leder_revised_codes\\python_notebooks\\normal_nvivo_df_spss.txt" \n \
  /ENCODING=\'UTF8\' \n \
  /DELCASE=LINE \n \
  /DELIMITERS="\\t" \n \
  /ARRANGEMENT=DELIMITED \n \
  /FIRSTCASE=2 \n \
  /DATATYPEMIN PERCENTAGE=95.0 \n \
  /VARIABLES= \n ')

file.write(spps_syntax_for_normal_nvivo_vars)



file.write('/MAP. \n \
RESTORE. \n \
CACHE. \n \
EXECUTE. \n \
DATASET NAME nvivo_data_normal_reviews WINDOW=FRONT. \n')

file.close()

# %%
# %pwd
# Out:
# '\\\\ads\\filestore\\Deaf_Studies\\Deaf\\nfrc\\LeDeR confidential\\Data Entry\\Avon\\reviews_leder_revised_codes\\python_notebooks'

# %% [markdown]
# # Obtain possibly significant correlations:
# between target variable and all others (where p-vale <0.05)

# %%
# function to check if at least five entries in each cell of the crosstab
def check_if_valid_crosstab(a_crosstab):
    z = a_crosstab > 5
    z1 = z.values.tolist() # make df a list of lists
    flat_list = [item for sublist in z1 for item in sublist]
    validity = all(flat_list)
    return(validity)

# %%
numeric_columns_only_df = normal_df_no_dups.select_dtypes('float64')
for n in range(len(numeric_columns_only_df.columns)):
    x = pd.crosstab(normal_df_no_dups.Clinical_pneumonia_aspiration, numeric_columns_only_df.iloc[:,n])
    y=check_if_valid_crosstab(x)
    if y:
        z = chi2_contingency(x)
        p_value = z[1]
        if p_value < 0.05:
            print(x.index.name,' vs ',x.columns.name, ': ',round(p_value,3))
# Out:
# Clinical_pneumonia_aspiration  vs  AP_raised_EOL_care :  0.025
# Clinical_pneumonia_aspiration  vs  AP_raised_care_coordination :  0.037
# Clinical_pneumonia_aspiration  vs  Acm_TOD_dur_LT_5years :  0.04
# Clinical_pneumonia_aspiration  vs  Acm_TOD_dur_cat :  0.002
# Clinical_pneumonia_aspiration  vs  Agency_safeguarding_referral :  0.014
# Clinical_pneumonia_aspiration  vs  Any_aids_employed :  0.0
# Clinical_pneumonia_aspiration  vs  Aspiration_before_last_year :  0.037
# Clinical_pneumonia_aspiration  vs  Aspiration_within_last_year :  0.0
# Clinical_pneumonia_aspiration  vs  Blood_pressure_high :  0.025
# Clinical_pneumonia_aspiration  vs  Blood_pressure_low :  0.0
# Clinical_pneumonia_aspiration  vs  Cancer :  0.0
# Clinical_pneumonia_aspiration  vs  Cancer_main_symptom :  0.0
# Clinical_pneumonia_aspiration  vs  Care_plan_EOL :  0.0
# Clinical_pneumonia_aspiration  vs  Care_plan_dementia :  0.019
# Clinical_pneumonia_aspiration  vs  Care_plan_epilepsy :  0.027
# Clinical_pneumonia_aspiration  vs  Choking_within_last_year :  0.002
# Clinical_pneumonia_aspiration  vs  Circumstances_of_death :  0.043
# Clinical_pneumonia_aspiration  vs  Clinical_COPD :  0.046
# Clinical_pneumonia_aspiration  vs  Clinical_autism :  0.025
# Clinical_pneumonia_aspiration  vs  Clinical_cerebral_palsy :  0.0
# Clinical_pneumonia_aspiration  vs  Clinical_dementia :  0.0
# Clinical_pneumonia_aspiration  vs  Clinical_double_incontinence :  0.0
# Clinical_pneumonia_aspiration  vs  Clinical_downs :  0.001
# Clinical_pneumonia_aspiration  vs  Clinical_history_chest_infections :  0.0
# Clinical_pneumonia_aspiration  vs  Clinical_sepsis :  0.0
# Clinical_pneumonia_aspiration  vs  Communication_abilities :  0.03
# Clinical_pneumonia_aspiration  vs  Constipation :  0.027
# Clinical_pneumonia_aspiration  vs  Continence_aids :  0.041
# Clinical_pneumonia_aspiration  vs  DNACPR_comments :  0.0
# Clinical_pneumonia_aspiration  vs  Dental_regular_care :  0.025
# Clinical_pneumonia_aspiration  vs  Epilepsy :  0.0
# Clinical_pneumonia_aspiration  vs  Fam_rel_poor :  0.048
# Clinical_pneumonia_aspiration  vs  Family_carers_views_of_death :  0.025
# Clinical_pneumonia_aspiration  vs  Fear_of_doctor_or_treatment :  0.025
# Clinical_pneumonia_aspiration  vs  Health :  0.017
# Clinical_pneumonia_aspiration  vs  Health_checks_anual_LD :  0.017
# Clinical_pneumonia_aspiration  vs  Hospital_communication_document_yes :  0.005
# Clinical_pneumonia_aspiration  vs  Housing_provider :  0.009
# Clinical_pneumonia_aspiration  vs  LD_severity_mild :  0.001
# Clinical_pneumonia_aspiration  vs  Living_alone :  0.01
# Clinical_pneumonia_aspiration  vs  Living_with_other_residents :  0.022
# Clinical_pneumonia_aspiration  vs  MCA_comments :  0.029
# Clinical_pneumonia_aspiration  vs  Medical_intervention_details :  0.017
# Clinical_pneumonia_aspiration  vs  Meds_antiepileptics :  0.002
# Clinical_pneumonia_aspiration  vs  Mental_health_other :  0.021
# Clinical_pneumonia_aspiration  vs  Mobility_total_support :  0.0
# Clinical_pneumonia_aspiration  vs  Motor_impairement :  0.006
# Clinical_pneumonia_aspiration  vs  Motor_impairment :  0.011
# Clinical_pneumonia_aspiration  vs  Motore_impairment_hand :  0.018
# Clinical_pneumonia_aspiration  vs  No_verbal_communication :  0.0
# Clinical_pneumonia_aspiration  vs  Nursing_LD_liaison_nurse :  0.0
# Clinical_pneumonia_aspiration  vs  Nursing_PEG_nurse :  0.005
# Clinical_pneumonia_aspiration  vs  Nursing_home_dementia :  0.003
# Clinical_pneumonia_aspiration  vs  Nursing_home_generic :  0.001
# Clinical_pneumonia_aspiration  vs  Nursing_hospital_palliative_nurse :  0.028
# Clinical_pneumonia_aspiration  vs  Patients_family_brought_in :  0.0
# Clinical_pneumonia_aspiration  vs  Person_refused_treatment :  0.001
# Clinical_pneumonia_aspiration  vs  Personal_healthcare_full_support :  0.0
# Clinical_pneumonia_aspiration  vs  Personal_healthcare_independent :  0.017
# Clinical_pneumonia_aspiration  vs  Personal_healthcare_some_support :  0.019
# Clinical_pneumonia_aspiration  vs  Poor_practice_care_coordination :  0.049
# Clinical_pneumonia_aspiration  vs  Poor_practice_secondary :  0.001
# Clinical_pneumonia_aspiration  vs  Posture_needs :  0.0
# Clinical_pneumonia_aspiration  vs  Pressure_sores :  0.04
# Clinical_pneumonia_aspiration  vs  Previous_hospital_admissions :  0.0
# Clinical_pneumonia_aspiration  vs  Prof_SALT :  0.0
# Clinical_pneumonia_aspiration  vs  Prof_SALT_generic :  0.025
# Clinical_pneumonia_aspiration  vs  Prof_dietician :  0.0
# Clinical_pneumonia_aspiration  vs  Prof_neurologist :  0.045
# Clinical_pneumonia_aspiration  vs  Prof_physiotherapist :  0.001
# Clinical_pneumonia_aspiration  vs  Prof_psychiatrist :  0.039
# Clinical_pneumonia_aspiration  vs  Reasonable_adjustments :  0.026
# Clinical_pneumonia_aspiration  vs  Reasonable_adjustments_made_helpers_in_hospital :  0.0
# Clinical_pneumonia_aspiration  vs  Residential_home_LD :  0.043
# Clinical_pneumonia_aspiration  vs  Residential_home_generic :  0.037
# Clinical_pneumonia_aspiration  vs  Residential_home_some_LD :  0.022
# Clinical_pneumonia_aspiration  vs  Seizures_in_last_5_years :  0.0
# Clinical_pneumonia_aspiration  vs  Skin_problems_past :  0.008
# Clinical_pneumonia_aspiration  vs  Sleep_system_used :  0.048
# Clinical_pneumonia_aspiration  vs  Swallow_PEG_PEJ :  0.0
# Clinical_pneumonia_aspiration  vs  Swallow_assess_before_last_year :  0.001
# Clinical_pneumonia_aspiration  vs  Swallow_assess_within_last_year :  0.0
# Clinical_pneumonia_aspiration  vs  Swallow_food_mashed :  0.0
# Clinical_pneumonia_aspiration  vs  Swallow_food_pureed :  0.0
# Clinical_pneumonia_aspiration  vs  Swallow_food_supplements :  0.0
# Clinical_pneumonia_aspiration  vs  Swallow_history_aspiration :  0.0
# Clinical_pneumonia_aspiration  vs  Swallow_nasogastric :  0.0
# Clinical_pneumonia_aspiration  vs  Swallow_prior_actions :  0.0
# Clinical_pneumonia_aspiration  vs  Swallowing_assessment :  0.0
# Clinical_pneumonia_aspiration  vs  Swallowing_issues_dysphagia :  0.0
# Clinical_pneumonia_aspiration  vs  Vision_problems_yes :  0.013

# %%
normal_df_no_dups.coder_atext.unique()
# Out:
# array(['nick', 'karen', 'ann', 'nicholasm', 'kamila'], dtype=object)

# %%
x=pd.DataFrame(numeric_columns_only_df.sum(axis=0))
x.to_csv('numbers_of_each_code.csv')

# %%
x
# Out:
#                                          0
# AAA_screening                          1.0
# AAA_screening_no                       1.0
# AAA_screening_yes                      2.0
# AP_agencies                           39.0
# AP_completed_DNACPR                    4.0
# AP_completed_EOL_care                  6.0
# AP_completed_LD_awareness             19.0
# AP_completed_MCA                      20.0
# AP_completed_agencies                 38.0
# AP_completed_care_coordination        30.0
# AP_completed_documentation            19.0
# AP_completed_family                    0.0
# AP_completed_other                    14.0
# AP_completed_reasonable_adjustments   14.0
# AP_completed_role_paid_carers          8.0
# AP_person                              5.0
# AP_raised_DNACPR                      63.0
# AP_raised_EOL_care                   159.0
# AP_raised_LD_awareness               276.0
# AP_raised_MCA                        255.0
# AP_raised_agencies                   347.0
# AP_raised_care_coordination          416.0
# AP_raised_documentation              279.0
# AP_raised_family                      35.0
# AP_raised_other                      254.0
# AP_raised_reasonable_adjustments     185.0
# AP_raised_role_paid_carers            93.0
# Absences_1_to_4_per_month              1.0
# Absences_frequency                     4.0
# Accident_incident                     10.0
# ...                                    ...
# Surgery_last_year                     98.0
# Swallow_PEG_PEJ                      171.0
# Swallow_assess_before_last_year       96.0
# Swallow_assess_unknown                16.0
# Swallow_assess_within_last_year      222.0
# Swallow_breathless_eating              1.0
# Swallow_feeding_drink_problem         15.0
# Swallow_food_cut                      37.0
# Swallow_food_mashed                   80.0
# Swallow_food_pureed                  196.0
# Swallow_food_supplements             331.0
# Swallow_history_aspiration            23.0
# Swallow_history_choking               17.0
# Swallow_nasogastric                   99.0
# Swallow_prior_actions                137.0
# Swallow_special_seating                8.0
# Swallowing_assessment                 34.0
# Swallowing_issues                      5.0
# Swallowing_issues_dysphagia          487.0
# Targeted_by_others                    53.0
# Treatment_escalation_plan             17.0
# Unmet_needs                          164.0
# Useful_material_without_code         362.0
# Useful_quote                          53.0
# Usually_lives_with                   373.0
# Verbal_skills                         39.0
# Vision_problems                       16.0
# Vision_problems_no                    14.0
# Vision_problems_yes                  378.0
# Weight                               252.0
#
# [578 rows x 1 columns]

# %% [markdown]
# ## print datetime to confirm run completion time, and then exit

# %%
import datetime
print('JOB COMPLETE AT: ',str(datetime.datetime.now()).split('.')[0])
# Out:
# JOB COMPLETE AT:  2019-07-04 10:54:57
